# %%
import pprint
import sys
import numpy as np
import pandas as pd
eps = np.finfo(float).eps
from numpy import log2 as log

# %%
a=pd.read_csv('train_data.csv')
a.describe()

df = pd.DataFrame(a)#,columns=['Work_accident','promotion_last_5years','sales','salary','left'])

# %%
# train, validate = np.split(df, [int(.8*len(df))]) #for sequential data
train, validate = np.split(df.sample(frac=1), [int(.8*len(df))]) # for random

# %%
numerical_attributes=[]
for i in df.keys()[0:5]:
    numerical_attributes.append(i)
#     print(i)
# print numerical_attributes

# %% [markdown]
# ## For misclassification :

# %%
def find_misclassification(dframe):
    Class = 'left'   #To make the code generic, changing target variable class name
    miscl = 100
    frc=[]
    

#     values = dframe['left'].unique()
#     for value in values:
#         f1=float(dframe['left'].value_counts()[value]/float(len(dframe[Class])))
#         frc.append(f1)
        
#     print frc
    
#     if len(frc) == 1:
#         return 0
#     if frc[0]<miscl:
#         min_misc=frc[0]
# #         return frc[0]
#     if frc[1]<frc[0]:
#         min_misc=frc[1]
#     return min_misc
    
    min_=100
    values = dframe['left'].unique()
    for value in values:            
        fraction = dframe['left'].value_counts()[value]/float(len(dframe['left']))
        if(fraction<min_):
            min_=fraction
    return min_

    
    
#     print df['left'].value_counts()[0]
#     fraction1 = df['left'].value_counts()[0]/float(len(df[Class]))
#     fraction2 = 1-float(fraction1)

#     miscl = min(frc[0],frc[1])
    
#     return (miscl)

print find_misclassification(train)
# Out:
# 0.235372636263

# %%
#gini of categorical
def find_misclassification_attribute(df,attribute):
    Class = 'left'   #To make the code generic, changing target variable class name
    target_variables = df[Class].unique()  #This gives all 'Yes' and 'No'
    variables = df[attribute].unique()    #This gives different features in that attribute (like 'Hot','Cold' in Temperature)
    if len(target_variables) == 1 or len(variables) == 1:
        return 0;
    miscl_finl = 0
    for variable in variables:
        entropy = 1
        num = len(df[attribute][df[attribute]==variable][df[Class] ==1])
        den= len(df[attribute][df[attribute]==variable])
        fr1 = num/(den+eps)
#         entropy *= fraction
#         entropy*=float(1-fraction)
        entropy_fin=min(fr1,float(1-fr1))
#         print entropy_fin
        x=den/float(len(df))
#         print(len(df))
        miscl_finl +=entropy_fin*x
    return miscl_finl

# print find_misclassification_attribute(df,'promotion_last_5years')

# #0.238 promotion_last_5years

# %%
#numerical attributes gini
def min_num_misclassification(df,attribute):
    variables = df[attribute].unique()    #This gives different features in that attribute (like 'Hot','Cold' in Temperature)
    entropy2 = 0
    entropy1 = 0
    min_entr=sys.maxint
    min_split=sys.maxint
    entropy_fin=0
    for variable in variables:
        entropy = 0
        df1 = df[df[attribute]<=variable]
        df2 = df[df[attribute]>variable]
#         entropy1 = find_misclassification(df1)
        
        min_=100
        values = df1['left'].unique()
        for value in values:            
            fraction = df1['left'].value_counts()[value]/float(len(df1['left']))
            if(fraction<min_):
                min_=fraction
        entropy1=min_
            
#         entropy2 = find_misclassification(df2)
        
        min_=100
        values = df2['left'].unique()
        for value in values:            
            fraction = df2['left'].value_counts()[value]/float(len(df2['left']))
            if(fraction<min_):
                min_=fraction
        entropy2=min_
        
        fraction2 = len(df2)/float(len(df))
        fraction1 = len(df1)/float(len(df))
        entropy_fin = fraction1*entropy1+ fraction2*entropy2
        
        if min_entr>entropy_fin:
            min_entr=entropy_fin
            min_split=variable

    return min_entr,min_split
 
    
# print min_num_misclassification(df,'satisfaction_level')    
# (0.17921338316426411, 0.46000000000000002

# %%
def max_IG_misc(dataf):    
    IG = []
    i=0
    split=-1
    max_=0
    max_in=None
    #categ
    for key in dataf.keys()[5:-1]:
        if key!= 'left':
            temp_en = find_misclassification_attribute(dataf,key) 
#             print temp_en
            ig1= find_misclassification(dataf)-temp_en      
#             print("IG 1: ",ig1,key)        
            if ig1>max_:
                max_=ig1
                max_in=key
            IG.append(ig1)

    #continuous
    for key in dataf.keys()[0:5]:
        temp_en = min_num_misclassification(dataf,key)[0]
        ig1=find_misclassification(dataf)-temp_en    
#         print("IG 2conti: ",ig1,key)        
        if ig1>max_:
            max_=ig1
            max_in=key
            split=min_num_misclassification(dataf,key)[1]      

        IG.append(ig1)
#     print 'ig=',IG
    return max_in,max_,split,IG

# max_IG(df)
# print max_IG(train)

# %%
class DTree:
    def __init__(self,pos=0,neg=0, child={},val = None,spl_pt=-1):
        self.val = val
        self.child = child
        self.pos=pos
        self.neg=neg
        self.spl_pt=spl_pt
        

def buildTree_misc(df1,label_node,tree=None):
    max_ig_node,gn,split,Info_gain_array = max_IG_misc(df1)
#     print max_ig_node,gn,split
#     dd=find_entropy_attribute(df1,label_node)
#     print 'MAX IG= ',gn,'split=',split
#     pprint.pprint(max_ig_node)

    c_pos=0
    c_len=0
    
    
    if gn <= 0.000001 or len(df1.columns)==1:
#         print 'IG-array',Info_gain_array
           ########switched 0 and 1
        c_pos=len(df1[df1[label_node]==1])
        c_len=len(df1[df1[label_node]==0])
        if c_pos>c_len:
            max_ig_node="YES"
        else:
            max_ig_node="NO"
        child={}
#         print "leaf nnode hai"
        leaf_n=DTree(c_pos,c_len,child,max_ig_node)
        return leaf_n

    print 'node is--- ',max_ig_node
    c_pos=len(df1[max_ig_node][df1[label_node]==1])
    c_len=len(df1[max_ig_node][df1[label_node]==0])
    child={}
    
    
    
    if split==-1:
        newnode=DTree(c_pos,c_len,child,max_ig_node,-1)
        attr = df1[max_ig_node].unique()
      
        for labels in attr:
            nd1=df1[df1[max_ig_node]==labels]
            nd1=nd1.drop(columns=[max_ig_node])
            newnode.spl_pt=-1
            newnode.child[labels] = buildTree_misc(nd1,label_node) #Calling the function recursively 

    else:
        newnode=DTree(c_pos,c_len,child,max_ig_node,split)
        label1="<="+str(split)
        label2=">"+str(split)   
#         print "numericl ka bno"
        nd1=df1[df1[max_ig_node]<=split]
        nd2=df1[df1[max_ig_node]>split]
#         print len(nd1)
#         print len(nd2)
        if len(nd1)==0 or len(nd2)==0:
            c_pos=len(df1[df1[label_node]==1])
            c_len=len(df1[df1[label_node]==0])
            if c_pos>c_len:
                max_ig_node="YES"
            else:
                max_ig_node="NO"
            child={}
#             print "leaf nnode hai"
            leaf_n=DTree(c_pos,c_len,child,max_ig_node)
            return leaf_n
#         if len(nd2
        newnode.child[label1] = buildTree_misc(nd1,label_node) #Calling the function recursively 
        newnode.child[label2] = buildTree_misc(nd2,label_node) #Calling the function recursively 
    return newnode

# %%
def traverse(tree):
    print(tree.val) #,'split=',tree.spl_pt)
    if tree.val==1:
        return
    for k,vals in tree.child.items():
        pprint.pprint(k)
        traverse(vals)
    
tree_m = buildTree_misc(train,'left')
pprint.pprint("tree")

traverse(tree_m)
# pprint.pprint(tree.val)
# Out:
# node is---  satisfaction_level
# node is---  last_evaluation
# node is---  promotion_last_5years
# node is---  Work_accident
# node is---  sales
# node is---  salary
# node is---  number_project
# node is---  satisfaction_level
# node is---  average_montly_hours
# node is---  last_evaluation
# node is---  satisfaction_level
# node is---  promotion_last_5years
# node is---  sales
# node is---  Work_accident
# node is---  salary
# node is---  Work_accident
# node is---  salary
# node is---  Work_accident
# node is---  salary
# node is---  Work_accident
# node is---  salary
# node is---  Work_accident
# node is---  salary
# node is---  salary
# node is---  Work_accident
# node is---  salary
# node is---  promotion_last_5years
# node is---  promotion_last_5years
# node is---  last_evaluation
# node is---  promotion_last_5years
# node is---  Work_accident
# node is---  salary
# node is---  sales
# node is---  sales
# node is---  sales
# node is---  salary
# node is---  last_evaluation
# node is---  average_montly_hours
# node is---  promotion_last_5years
# node is---  sales
# node is---  Work_accident
# node is---  salary
# node is---  Work_accident
# node is---  salary
# node is---  Work_accident
# node is---  salary
# node is---  Work_accident
# node is---  salary
# node is---  Work_accident
# node is---  salary
# node is---  Work_accident
# node is---  salary
# node is---  time_spend_company
# node is---  satisfaction_level
# 'tree'
# satisfaction_level
# '<=0.12'
# last_evaluation
# '>0.61'
# YES
# '<=0.61'
# promotion_last_5years
# 0
# Work_accident
# 0
# NO
# 1
# sales
# 'RandD'
# salary
# 'low'
# YES
# '>0.12'
# number_project
# '<=2'
# satisfaction_level
# '<=0.46'
# average_montly_hours
# '>161'
# promotion_last_5years
# 0
# NO
# '<=161'
# last_evaluation
# '<=0.57'
# satisfaction_level
# '<=0.34'
# promotion_last_5years
# 0
# sales
# 'technical'
# Work_accident
# 0
# salary
# 'high'
# NO
# 'medium'
# NO
# 'low'
# NO
# 'support'
# Work_accident
# 1
# salary
# 'medium'
# NO
# 'sales'
# Work_accident
# 0
# salary
# 'medium'
# NO
# 'low'
# YES
# 'RandD'
# Work_accident
# 0
# salary
# 'medium'
# NO
# 'low'
# NO
# 'hr'
# Work_accident
# 0
# salary
# 'medium'
# NO
# 1
# salary
# 'low'
# NO
# 'accounting'
# Work_accident
# 0
# salary
# 'medium'
# NO
# '>0.34'
# YES
# '>0.57'
# promotion_last_5years
# 0
# NO
# '>0.46'
# last_evaluation
# '<=0.99'
# NO
# '>0.99'
# promotion_last_5years
# 0
# Work_accident
# 0
# salary
# 'medium'
# sales
# 'marketing'
# NO
# 'low'
# sales
# 'sales'
# YES
# 'RandD'
# YES
# 'product_mng'
# YES
# 1
# sales
# 'sales'
# salary
# 'low'
# NO
# '>2'
# last_evaluation
# '<=0.99'
# average_montly_hours
# '<=286'
# NO
# '>286'
# promotion_last_5years
# 0
# sales
# 'hr'
# Work_accident
# 0
# salary
# 'low'
# YES
# 'marketing'
# Work_accident
# 0
# salary
# 'low'
# YES
# 'support'
# Work_accident
# 0
# salary
# 'medium'
# NO
# 'low'
# YES
# 'sales'
# NO
# 'RandD'
# Work_accident
# 0
# salary
# 'high'
# NO
# 'low'
# NO
# 'IT'
# Work_accident
# 0
# salary
# 'medium'
# YES
# 'low'
# YES
# 'technical'
# Work_accident
# 0
# salary
# 'medium'
# NO
# '>0.99'
# time_spend_company
# '>4'
# satisfaction_level
# '>0.68'
# YES
# '<=0.68'
# NO
# '<=4'
# NO

# %%
def predict(row,tree):
#     global tp,tn,fp,fn
    if tree.val=="YES" or tree.val=="NO":
        return tree.val
    
    attr=row[tree.val]
    
    if tree.val in numerical_attributes:
        if attr<=tree.spl_pt:
            x="<="+str(tree.spl_pt)
            return predict(row,tree.child[x])
        else:
            x=">"+str(tree.spl_pt)
            return predict(row,tree.child[x])
    else:
        if attr in tree.child:
            return predict(row,tree.child[attr])
    return "NO"

def predict1(df,tree):
    tp=0
    tn=0
    fp=0
    fn=0
    i=0
    while i< len(df):
        pred_val=predict(df.iloc[i],tree)
        if df.iloc[i]['left']==1:
            if pred_val=="YES":
                tp=tp+1
            else:
                fn=fn+1 #### fn here 
        elif df.iloc[i]['left']==0:
            if pred_val=="NO":
                tn=tn+1
            else:
                fp=fp+1 #### fp here
        i=i+1
#         print"i="
    return tp,fp,tn,fn
    
        
# row=df.iloc[8]
# print (row)
tp,fp,tn,fn=predict1(validate,tree_m)
print 'For misclassification:-'
print "True Positive=\t",tp
print "True Negative=\t",tn
print "False positive=",fp
print "False negative=",fn
total=tp+tn+fp+fn
prec=tp/float(tp+fp)
rec=tp/float(tp+fn)
den=float((1/rec)+(1/prec))
f1=2/float(den)

print "Precision: ", prec
print "Recall: ",rec
print "F1 score: ",f1
print "accuracy: ",(tp+tn)/float(total)

# pred=predict(row,tree)
# pprint.pprint(pred)
# Out:
# For misclassification:-
# True Positive=	423
# True Negative=	1677
# False positive= 12
# False negative= 136
# Precision:  0.972413793103
# Recall:  0.756708407871
# F1 score:  0.851106639839
# accuracy:  0.934163701068

# %% [markdown]
# ## For entropy:

# %%
def find_entropy(df):
    Class = 'left'   #To make the code generic, changing target variable class name
    entropy = 0
    values = df['left'].unique()
    for value in values:
        fraction = df['left'].value_counts()[value]/float(len(df[Class]))
        entropy += -fraction*np.log2(fraction+eps)
    return entropy




def find_entropy_attribute(df,attribute):
    Class = 'left'   #To make the code generic, changing target variable class name
    target_variables = df[Class].unique()  #This gives all 'Yes' and 'No'
    variables = df[attribute].unique()    #This gives different features in that attribute (like 'Hot','Cold' in Temperature)
    if len(target_variables) == 1 or len(variables) == 1:
        return 0;
    entropy2 = 0
    for variable in variables:
        entropy = 0
        for target_variable in target_variables:
            num = len(df[attribute][df[attribute]==variable][df[Class] ==target_variable])
            den = len(df[attribute][df[attribute]==variable])
            fraction = num/(den+eps)
            entropy += -fraction*np.log2(fraction+eps)
        fraction2 = den/float(len(df))
        entropy2 += fraction2*entropy
    return entropy2



def min_num_entropy(df,attribute):
#     temp_d=df    
#     x=temp_d.sort_values(by=attribute)
#     print "min_continuous entropy"
#     variables = x[attribute].unique()
  
    variables = df[attribute].unique()    #This gives different features in that attribute (like 'Hot','Cold' in Temperature)
    entropy2 = 0
    entropy1 = 0
    min_entr=sys.maxint
    min_split=sys.maxint
    entropy_fin=0
    for variable in variables:
        entropy = 0
        df1 = df[df[attribute]<=variable]
        df2 = df[df[attribute]>variable]
        entropy1 = find_entropy(df1)
        entropy2 = find_entropy(df2)

        
        fraction2 = len(df2)/float(len(df))
        fraction1 = len(df1)/float(len(df))
        entropy_fin = fraction1*entropy1+ fraction2*entropy2
        
        if min_entr>entropy_fin:
            min_entr=entropy_fin
            min_split=variable

    return min_entr,min_split
 
    
# print min_num_entropy(df,'satisfaction_level')

# %%
def max_IG_en(dataf):    
    IG = []
    i=0
    split=-1
    max_=0
    max_in=None
    #categ
    for key in dataf.keys()[5:-1]:
        if key!= 'left':
            temp_en = find_entropy_attribute(dataf,key) 
#             print temp_en
            ig1= find_entropy(dataf)-temp_en      
#             print("IG 1: ",ig1,key)        
            if ig1>max_:
                max_=ig1
                max_in=key
            IG.append(ig1)

    #continuous
    for key in dataf.keys()[0:5]:
        temp_en = min_num_entropy(dataf,key)[0]
        ig1=find_entropy(dataf)-temp_en    
#         print("IG 2conti: ",ig1,key)        
        if ig1>max_:
            max_=ig1
            max_in=key
            split=min_num_entropy(dataf,key)[1]      

        IG.append(ig1)
#     print 'ig=',IG
    return max_in,max_,split,IG

# max_IG(df)

# %%
class DTree:
    def __init__(self,pos=0,neg=0, child={},val = None,spl_pt=-1):
        self.val = val
        self.child = child
        self.pos=pos
        self.neg=neg
        self.spl_pt=spl_pt
        

def buildTree_en(df1,label_node,tree=None):
    max_ig_node,gn,split,Info_gain_array = max_IG_en(df1)
#     print max_ig_node,gn,split
#     dd=find_entropy_attribute(df1,label_node)
#     print 'MAX IG= ',gn,'split=',split
#     pprint.pprint(max_ig_node)

    c_pos=0
    c_len=0
    
    
    if gn <= 0.000001 or len(df1.columns)==1:
#         print 'IG-array',Info_gain_array
           ########switched 0 and 1
        c_pos=len(df1[df1[label_node]==1])
        c_len=len(df1[df1[label_node]==0])
        if c_pos>c_len:
            max_ig_node="YES"
        else:
            max_ig_node="NO"
        child={}
#         print "leaf nnode hai"
        leaf_n=DTree(c_pos,c_len,child,max_ig_node)
        return leaf_n

    print 'node is--- ',max_ig_node
    c_pos=len(df1[max_ig_node][df1[label_node]==1])
    c_len=len(df1[max_ig_node][df1[label_node]==0])
    child={}
    
    
    
    if split==-1:
        newnode=DTree(c_pos,c_len,child,max_ig_node,-1)
        attr = df1[max_ig_node].unique()
      
        for labels in attr:
            nd1=df1[df1[max_ig_node]==labels]
            nd1=nd1.drop(columns=[max_ig_node])
            newnode.spl_pt=-1
            newnode.child[labels] = buildTree_en(nd1,label_node) #Calling the function recursively 

    else:
        newnode=DTree(c_pos,c_len,child,max_ig_node,split)
        label1="<="+str(split)
        label2=">"+str(split)   
#         print "numericl ka bno"
        nd1=df1[df1[max_ig_node]<=split]
        nd2=df1[df1[max_ig_node]>split]
#         print len(nd1)
#         print len(nd2)
        if len(nd1)==0 or len(nd2)==0:
            c_pos=len(df1[df1[label_node]==1])
            c_len=len(df1[df1[label_node]==0])
            if c_pos>c_len:
                max_ig_node="YES"
            else:
                max_ig_node="NO"
            child={}
#             print "leaf nnode hai"
            leaf_n=DTree(c_pos,c_len,child,max_ig_node)
            return leaf_n

        newnode.child[label1] = buildTree_en(nd1,label_node) #Calling the function recursively 
        newnode.child[label2] = buildTree_en(nd2,label_node) #Calling the function recursively 
    return newnode

# %%
def traverse(tree):
    print(tree.val) #,'split=',tree.spl_pt)
    if tree.val==1:
        return
    for k,vals in tree.child.items():
        pprint.pprint(k)
        traverse(vals)
    
tree_e = buildTree_en(train,'left')
print "tree:-"

traverse(tree_e)
# pprint.pprint(tree.val)
# Out:
# node is---  satisfaction_level
# node is---  number_project
# node is---  average_montly_hours
# node is---  last_evaluation
# node is---  last_evaluation
# node is---  average_montly_hours
# node is---  satisfaction_level
# node is---  satisfaction_level
# node is---  salary
# node is---  average_montly_hours
# node is---  average_montly_hours
# node is---  promotion_last_5years
# node is---  satisfaction_level
# node is---  satisfaction_level
# node is---  promotion_last_5years
# node is---  sales
# node is---  satisfaction_level
# node is---  promotion_last_5years
# node is---  sales
# node is---  average_montly_hours
# node is---  promotion_last_5years
# node is---  satisfaction_level
# node is---  average_montly_hours
# node is---  satisfaction_level
# node is---  last_evaluation
# node is---  average_montly_hours
# node is---  satisfaction_level
# node is---  number_project
# node is---  sales
# node is---  last_evaluation
# node is---  satisfaction_level
# node is---  average_montly_hours
# node is---  satisfaction_level
# node is---  average_montly_hours
# node is---  last_evaluation
# node is---  last_evaluation
# node is---  average_montly_hours
# node is---  last_evaluation
# node is---  satisfaction_level
# node is---  promotion_last_5years
# node is---  last_evaluation
# node is---  last_evaluation
# node is---  time_spend_company
# node is---  last_evaluation
# node is---  salary
# node is---  last_evaluation
# node is---  average_montly_hours
# node is---  promotion_last_5years
# node is---  satisfaction_level
# node is---  satisfaction_level
# node is---  promotion_last_5years
# node is---  number_project
# node is---  last_evaluation
# node is---  average_montly_hours
# node is---  salary
# node is---  satisfaction_level
# node is---  average_montly_hours
# node is---  satisfaction_level
# node is---  satisfaction_level
# node is---  average_montly_hours
# node is---  average_montly_hours
# node is---  satisfaction_level
# node is---  satisfaction_level
# node is---  average_montly_hours
# node is---  last_evaluation
# node is---  Work_accident
# node is---  salary
# node is---  satisfaction_level
# node is---  last_evaluation
# node is---  last_evaluation
# node is---  promotion_last_5years
# node is---  satisfaction_level
# node is---  salary
# node is---  last_evaluation
# node is---  promotion_last_5years
# node is---  average_montly_hours
# node is---  average_montly_hours
# node is---  average_montly_hours
# node is---  Work_accident
# node is---  number_project
# node is---  average_montly_hours
# node is---  satisfaction_level
# node is---  satisfaction_level
# node is---  last_evaluation
# node is---  time_spend_company
# node is---  average_montly_hours
# node is---  last_evaluation
# node is---  average_montly_hours
# node is---  satisfaction_level
# node is---  last_evaluation
# node is---  number_project
# node is---  promotion_last_5years
# node is---  average_montly_hours
# node is---  last_evaluation
# node is---  average_montly_hours
# node is---  last_evaluation
# node is---  satisfaction_level
# node is---  last_evaluation
# node is---  satisfaction_level
# node is---  time_spend_company
# node is---  average_montly_hours
# node is---  number_project
# node is---  number_project
# node is---  average_montly_hours
# node is---  last_evaluation
# node is---  promotion_last_5years
# node is---  sales
# node is---  satisfaction_level
# node is---  satisfaction_level
# node is---  last_evaluation
# node is---  sales
# node is---  satisfaction_level
# node is---  average_montly_hours
# node is---  satisfaction_level
# node is---  last_evaluation
# node is---  promotion_last_5years
# node is---  salary
# node is---  satisfaction_level
# node is---  Work_accident
# node is---  promotion_last_5years
# node is---  average_montly_hours
# node is---  satisfaction_level
# node is---  last_evaluation
# node is---  last_evaluation
# node is---  sales
# node is---  satisfaction_level
# node is---  satisfaction_level
# node is---  satisfaction_level
# node is---  last_evaluation
# node is---  last_evaluation
# node is---  number_project
# node is---  average_montly_hours
# node is---  average_montly_hours
# node is---  satisfaction_level
# node is---  satisfaction_level
# node is---  last_evaluation
# node is---  salary
# node is---  average_montly_hours
# node is---  satisfaction_level
# node is---  promotion_last_5years
# node is---  satisfaction_level
# node is---  average_montly_hours
# node is---  satisfaction_level
# node is---  promotion_last_5years
# node is---  average_montly_hours
# node is---  satisfaction_level
# node is---  last_evaluation
# node is---  last_evaluation
# node is---  promotion_last_5years
# node is---  last_evaluation
# node is---  salary
# node is---  satisfaction_level
# node is---  number_project
# node is---  promotion_last_5years
# node is---  average_montly_hours
# node is---  satisfaction_level
# node is---  average_montly_hours
# node is---  last_evaluation
# node is---  last_evaluation
# node is---  last_evaluation
# node is---  last_evaluation
# node is---  satisfaction_level
# node is---  last_evaluation
# node is---  average_montly_hours
# node is---  promotion_last_5years
# node is---  satisfaction_level
# node is---  last_evaluation
# node is---  satisfaction_level
# node is---  Work_accident
# node is---  satisfaction_level
# node is---  last_evaluation
# node is---  satisfaction_level
# node is---  promotion_last_5years
# node is---  salary
# node is---  number_project
# node is---  last_evaluation
# node is---  last_evaluation
# node is---  satisfaction_level
# node is---  time_spend_company
# node is---  number_project
# node is---  satisfaction_level
# node is---  promotion_last_5years
# node is---  satisfaction_level
# node is---  last_evaluation
# node is---  satisfaction_level
# node is---  last_evaluation
# node is---  salary
# node is---  satisfaction_level
# node is---  satisfaction_level
# node is---  last_evaluation
# node is---  last_evaluation
# node is---  satisfaction_level
# node is---  last_evaluation
# node is---  Work_accident
# node is---  promotion_last_5years
# node is---  time_spend_company
# node is---  average_montly_hours
# node is---  satisfaction_level
# node is---  time_spend_company
# node is---  average_montly_hours
# node is---  satisfaction_level
# node is---  satisfaction_level
# node is---  average_montly_hours
# node is---  average_montly_hours
# node is---  Work_accident
# node is---  satisfaction_level
# node is---  last_evaluation
# node is---  average_montly_hours
# node is---  average_montly_hours
# node is---  last_evaluation
# node is---  last_evaluation
# node is---  last_evaluation
# node is---  promotion_last_5years
# node is---  number_project
# node is---  last_evaluation
# node is---  satisfaction_level
# node is---  satisfaction_level
# node is---  satisfaction_level
# node is---  time_spend_company
# node is---  number_project
# node is---  last_evaluation
# node is---  average_montly_hours
# node is---  promotion_last_5years
# node is---  average_montly_hours
# node is---  satisfaction_level
# node is---  last_evaluation
# node is---  time_spend_company
# node is---  satisfaction_level
# node is---  satisfaction_level
# node is---  last_evaluation
# node is---  promotion_last_5years
# node is---  last_evaluation
# node is---  number_project
# node is---  last_evaluation
# node is---  satisfaction_level
# node is---  last_evaluation
# node is---  Work_accident
# node is---  promotion_last_5years
# node is---  last_evaluation
# node is---  satisfaction_level
# node is---  satisfaction_level
# node is---  sales
# node is---  promotion_last_5years
# node is---  time_spend_company
# node is---  satisfaction_level
# node is---  last_evaluation
# node is---  average_montly_hours
# node is---  average_montly_hours
# node is---  promotion_last_5years
# node is---  average_montly_hours
# node is---  satisfaction_level
# node is---  Work_accident
# node is---  satisfaction_level
# node is---  promotion_last_5years
# node is---  number_project
# node is---  salary
# node is---  last_evaluation
# node is---  satisfaction_level
# node is---  last_evaluation
# node is---  last_evaluation
# node is---  sales
# node is---  last_evaluation
# node is---  promotion_last_5years
# node is---  average_montly_hours
# node is---  Work_accident
# node is---  last_evaluation
# node is---  salary
# node is---  promotion_last_5years
# node is---  satisfaction_level
# node is---  Work_accident
# node is---  satisfaction_level
# node is---  last_evaluation
# node is---  satisfaction_level
# node is---  promotion_last_5years
# node is---  last_evaluation
# node is---  satisfaction_level
# node is---  satisfaction_level
# node is---  satisfaction_level
# node is---  average_montly_hours
# node is---  promotion_last_5years
# node is---  satisfaction_level
# node is---  satisfaction_level
# node is---  number_project
# node is---  last_evaluation
# node is---  satisfaction_level
# node is---  average_montly_hours
# node is---  satisfaction_level
# node is---  average_montly_hours
# node is---  last_evaluation
# node is---  time_spend_company
# node is---  promotion_last_5years
# node is---  number_project
# node is---  average_montly_hours
# node is---  Work_accident
# node is---  average_montly_hours
# node is---  sales
# node is---  satisfaction_level
# node is---  number_project
# node is---  satisfaction_level
# node is---  time_spend_company
# node is---  number_project
# node is---  promotion_last_5years
# node is---  satisfaction_level
# node is---  salary
# node is---  satisfaction_level
# node is---  promotion_last_5years
# node is---  last_evaluation
# node is---  last_evaluation
# node is---  satisfaction_level
# node is---  satisfaction_level
# node is---  satisfaction_level
# node is---  number_project
# node is---  sales
# node is---  average_montly_hours
# node is---  Work_accident
# node is---  promotion_last_5years
# node is---  number_project
# node is---  satisfaction_level
# node is---  promotion_last_5years
# node is---  last_evaluation
# node is---  last_evaluation
# node is---  average_montly_hours
# node is---  average_montly_hours
# node is---  Work_accident
# node is---  satisfaction_level
# node is---  satisfaction_level
# node is---  promotion_last_5years
# node is---  satisfaction_level
# node is---  average_montly_hours
# node is---  Work_accident
# node is---  last_evaluation
# node is---  satisfaction_level
# node is---  satisfaction_level
# tree:-
# satisfaction_level
# '<=0.46'
# number_project
# '<=2'
# average_montly_hours
# '>161'
# promotion_last_5years
# 0
# satisfaction_level
# '<=0.1'
# YES
# '>0.1'
# average_montly_hours
# '<=278'
# satisfaction_level
# '<=0.45'
# NO
# '>0.45'
# last_evaluation
# '<=0.82'
# NO
# '>0.82'
# YES
# '>278'
# average_montly_hours
# '>282'
# NO
# '<=282'
# YES
# '<=161'
# last_evaluation
# '<=0.57'
# last_evaluation
# '<=0.44'
# NO
# '>0.44'
# average_montly_hours
# '>125'
# satisfaction_level
# '<=0.31'
# satisfaction_level
# '<=0.11'
# YES
# '>0.11'
# NO
# '>0.31'
# salary
# 'high'
# promotion_last_5years
# 0
# sales
# 'product_mng'
# YES
# 'technical'
# YES
# 'marketing'
# YES
# 'support'
# satisfaction_level
# '<=0.36'
# NO
# '>0.36'
# YES
# 'sales'
# YES
# 'RandD'
# YES
# 'IT'
# NO
# 'accounting'
# YES
# 'medium'
# YES
# 'low'
# average_montly_hours
# '>150'
# average_montly_hours
# '>151'
# YES
# '<=151'
# promotion_last_5years
# 0
# satisfaction_level
# '>0.41'
# satisfaction_level
# '>0.42'
# YES
# '<=0.42'
# NO
# '<=0.41'
# YES
# '<=150'
# YES
# '<=125'
# NO
# '>0.57'
# promotion_last_5years
# 0
# sales
# 'management'
# NO
# 'product_mng'
# NO
# 'technical'
# average_montly_hours
# '<=139'
# NO
# '>139'
# YES
# 'marketing'
# NO
# 'support'
# NO
# 'sales'
# NO
# 'RandD'
# NO
# 'accounting'
# NO
# '>2'
# satisfaction_level
# '<=0.11'
# YES
# '>0.11'
# number_project
# '>6'
# YES
# '<=6'
# sales
# 'management'
# satisfaction_level
# '<=0.39'
# NO
# '>0.39'
# satisfaction_level
# '>0.42'
# NO
# '<=0.42'
# YES
# 'product_mng'
# NO
# 'technical'
# promotion_last_5years
# 0
# average_montly_hours
# '<=237'
# average_montly_hours
# '<=132'
# NO
# '>132'
# average_montly_hours
# '<=139'
# Work_accident
# 0
# YES
# 1
# NO
# '>139'
# number_project
# '>4'
# NO
# '<=4'
# average_montly_hours
# '>183'
# last_evaluation
# '>0.53'
# average_montly_hours
# '>188'
# average_montly_hours
# '<=236'
# NO
# '>236'
# satisfaction_level
# '<=0.36'
# YES
# '>0.36'
# NO
# '<=188'
# last_evaluation
# '>0.58'
# YES
# '<=0.58'
# NO
# '<=0.53'
# time_spend_company
# '>3'
# YES
# '<=3'
# NO
# '<=183'
# satisfaction_level
# '>0.14'
# NO
# '<=0.14'
# satisfaction_level
# '<=0.13'
# NO
# '>0.13'
# YES
# '>237'
# NO
# 'marketing'
# average_montly_hours
# '<=286'
# NO
# '>286'
# YES
# 'support'
# promotion_last_5years
# 0
# number_project
# '<=5'
# last_evaluation
# '<=0.99'
# average_montly_hours
# '>287'
# YES
# '<=287'
# NO
# '>0.99'
# YES
# '>5'
# salary
# 'high'
# satisfaction_level
# '>0.15'
# NO
# '<=0.15'
# YES
# 'medium'
# NO
# 'low'
# average_montly_hours
# '<=219'
# satisfaction_level
# '<=0.2'
# satisfaction_level
# '<=0.13'
# YES
# '>0.13'
# NO
# '>0.2'
# average_montly_hours
# '<=129'
# NO
# '>129'
# YES
# '>219'
# NO
# 'sales'
# last_evaluation
# '>0.52'
# satisfaction_level
# '<=0.29'
# average_montly_hours
# '>231'
# satisfaction_level
# '<=0.2'
# average_montly_hours
# '<=236'
# last_evaluation
# '>0.84'
# NO
# '<=0.84'
# YES
# '>236'
# last_evaluation
# '<=0.55'
# YES
# '>0.55'
# average_montly_hours
# '>275'
# last_evaluation
# '>0.63'
# YES
# '<=0.63'
# NO
# '<=275'
# NO
# '>0.2'
# NO
# '<=231'
# NO
# '>0.29'
# satisfaction_level
# '<=0.35'
# promotion_last_5years
# 0
# last_evaluation
# '<=0.88'
# last_evaluation
# '<=0.54'
# YES
# '>0.54'
# time_spend_company
# '>3'
# NO
# '<=3'
# last_evaluation
# '<=0.64'
# NO
# '>0.64'
# salary
# 'high'
# NO
# 'medium'
# YES
# 'low'
# last_evaluation
# '<=0.67'
# YES
# '>0.67'
# NO
# '>0.88'
# YES
# '>0.35'
# average_montly_hours
# '<=211'
# NO
# '>211'
# promotion_last_5years
# 0
# satisfaction_level
# '>0.42'
# satisfaction_level
# '<=0.45'
# YES
# '>0.45'
# NO
# '<=0.42'
# NO
# '<=0.52'
# NO
# 'RandD'
# last_evaluation
# '<=0.99'
# number_project
# '>3'
# promotion_last_5years
# 0
# average_montly_hours
# '>175'
# last_evaluation
# '<=0.82'
# NO
# '>0.82'
# satisfaction_level
# '<=0.29'
# NO
# '>0.29'
# YES
# '<=175'
# last_evaluation
# '>0.5'
# last_evaluation
# '>0.94'
# satisfaction_level
# '<=0.21'
# NO
# '>0.21'
# YES
# '<=0.94'
# NO
# '<=0.5'
# average_montly_hours
# '>126'
# YES
# '<=126'
# NO
# '<=3'
# NO
# '>0.99'
# YES
# 'IT'
# promotion_last_5years
# 0
# satisfaction_level
# '>0.14'
# NO
# '<=0.14'
# salary
# 'medium'
# last_evaluation
# '<=0.55'
# YES
# '>0.55'
# NO
# 'low'
# NO
# 'hr'
# NO
# 'accounting'
# average_montly_hours
# '>202'
# last_evaluation
# '<=0.65'
# Work_accident
# 0
# salary
# 'high'
# NO
# 'medium'
# last_evaluation
# '<=0.47'
# NO
# '>0.47'
# YES
# 'low'
# satisfaction_level
# '>0.24'
# YES
# '<=0.24'
# NO
# '>0.65'
# last_evaluation
# '<=0.98'
# NO
# '>0.98'
# YES
# '<=202'
# NO
# '>0.46'
# time_spend_company
# '>4'
# last_evaluation
# '<=0.8'
# sales
# 'management'
# NO
# 'product_mng'
# NO
# 'technical'
# salary
# 'high'
# satisfaction_level
# '<=0.8'
# YES
# '>0.8'
# NO
# 'medium'
# promotion_last_5years
# 0
# satisfaction_level
# '<=0.57'
# Work_accident
# 0
# satisfaction_level
# '>0.5'
# last_evaluation
# '>0.51'
# YES
# '<=0.51'
# NO
# '<=0.5'
# NO
# '>0.57'
# NO
# 'low'
# NO
# 'marketing'
# last_evaluation
# '<=0.67'
# NO
# '>0.67'
# satisfaction_level
# '<=0.56'
# NO
# '>0.56'
# YES
# 'support'
# last_evaluation
# '>0.6'
# promotion_last_5years
# 0
# average_montly_hours
# '<=156'
# NO
# '>156'
# Work_accident
# 0
# last_evaluation
# '>0.7'
# NO
# '<=0.7'
# YES
# 1
# NO
# '<=0.6'
# NO
# 'sales'
# NO
# 'RandD'
# average_montly_hours
# '<=190'
# NO
# '>190'
# promotion_last_5years
# 0
# satisfaction_level
# '>0.63'
# satisfaction_level
# '<=0.78'
# number_project
# '>3'
# YES
# '<=3'
# NO
# '>0.78'
# NO
# '<=0.63'
# NO
# 'IT'
# promotion_last_5years
# 0
# last_evaluation
# '>0.73'
# satisfaction_level
# '>0.53'
# NO
# '<=0.53'
# YES
# '<=0.73'
# NO
# 'hr'
# average_montly_hours
# '>275'
# satisfaction_level
# '>0.53'
# NO
# '<=0.53'
# YES
# '<=275'
# NO
# 'accounting'
# satisfaction_level
# '>0.85'
# satisfaction_level
# '<=0.89'
# YES
# '>0.89'
# NO
# '<=0.85'
# NO
# '>0.8'
# average_montly_hours
# '>216'
# time_spend_company
# '>6'
# NO
# '<=6'
# number_project
# '>3'
# satisfaction_level
# '>0.7'
# satisfaction_level
# '<=0.92'
# number_project
# '<=5'
# sales
# 'management'
# satisfaction_level
# '<=0.88'
# YES
# '>0.88'
# NO
# 'product_mng'
# YES
# 'technical'
# promotion_last_5years
# 0
# last_evaluation
# '>0.95'
# last_evaluation
# '<=0.99'
# average_montly_hours
# '<=255'
# average_montly_hours
# '<=254'
# Work_accident
# 0
# satisfaction_level
# '>0.86'
# YES
# '<=0.86'
# satisfaction_level
# '>0.85'
# NO
# '<=0.85'
# YES
# '>254'
# NO
# '>255'
# YES
# '>0.99'
# YES
# '<=0.95'
# YES
# 'marketing'
# YES
# 'support'
# promotion_last_5years
# 0
# satisfaction_level
# '<=0.91'
# average_montly_hours
# '<=271'
# YES
# '>271'
# Work_accident
# 0
# last_evaluation
# '>0.87'
# YES
# '<=0.87'
# satisfaction_level
# '<=0.8'
# YES
# '>0.8'
# NO
# '>0.91'
# NO
# 'sales'
# average_montly_hours
# '>223'
# YES
# '<=223'
# Work_accident
# 0
# promotion_last_5years
# 0
# number_project
# '>4'
# YES
# '<=4'
# satisfaction_level
# '>0.76'
# NO
# '<=0.76'
# YES
# 'RandD'
# YES
# 'IT'
# YES
# 'hr'
# YES
# 'accounting'
# YES
# '>5'
# NO
# '>0.92'
# NO
# '<=0.7'
# promotion_last_5years
# 0
# last_evaluation
# '<=0.91'
# last_evaluation
# '<=0.83'
# satisfaction_level
# '>0.61'
# YES
# '<=0.61'
# NO
# '>0.83'
# NO
# '>0.91'
# satisfaction_level
# '<=0.66'
# YES
# '>0.66'
# NO
# '<=3'
# promotion_last_5years
# 0
# satisfaction_level
# '>0.6'
# NO
# '<=0.6'
# salary
# 'medium'
# NO
# 'low'
# YES
# '<=216'
# last_evaluation
# '<=0.99'
# time_spend_company
# '<=5'
# promotion_last_5years
# 0
# number_project
# '>3'
# NO
# '<=3'
# average_montly_hours
# '<=156'
# NO
# '>156'
# Work_accident
# 0
# average_montly_hours
# '>183'
# NO
# '<=183'
# sales
# 'technical'
# satisfaction_level
# '>0.7'
# YES
# '<=0.7'
# NO
# 'support'
# YES
# 'sales'
# YES
# '>5'
# number_project
# '<=5'
# NO
# '>5'
# satisfaction_level
# '<=0.54'
# YES
# '>0.54'
# NO
# '>0.99'
# YES
# '<=4'
# average_montly_hours
# '>287'
# YES
# '<=287'
# number_project
# '<=5'
# number_project
# '<=2'
# average_montly_hours
# '>196'
# sales
# 'management'
# NO
# 'product_mng'
# NO
# 'technical'
# satisfaction_level
# '>0.48'
# average_montly_hours
# '>252'
# satisfaction_level
# '<=0.66'
# YES
# '>0.66'
# NO
# '<=252'
# NO
# '<=0.48'
# YES
# 'marketing'
# NO
# 'support'
# Work_accident
# 0
# promotion_last_5years
# 0
# average_montly_hours
# '<=211'
# satisfaction_level
# '<=0.8'
# YES
# '>0.8'
# NO
# '>211'
# NO
# 'sales'
# last_evaluation
# '>0.53'
# NO
# '<=0.53'
# promotion_last_5years
# 0
# salary
# 'medium'
# NO
# 'low'
# satisfaction_level
# '>0.7'
# NO
# '<=0.7'
# YES
# 'RandD'
# last_evaluation
# '<=0.9'
# NO
# '>0.9'
# YES
# 'IT'
# last_evaluation
# '>0.96'
# YES
# '<=0.96'
# NO
# 'hr'
# NO
# 'accounting'
# NO
# '<=196'
# last_evaluation
# '<=0.75'
# NO
# '>0.75'
# promotion_last_5years
# 0
# sales
# 'product_mng'
# NO
# 'hr'
# NO
# 'marketing'
# NO
# 'support'
# NO
# 'IT'
# NO
# 'RandD'
# last_evaluation
# '>0.76'
# NO
# '<=0.76'
# YES
# 'sales'
# satisfaction_level
# '>0.84'
# satisfaction_level
# '>0.85'
# NO
# '<=0.85'
# YES
# '<=0.84'
# NO
# 'technical'
# NO
# '>2'
# sales
# 'management'
# average_montly_hours
# '<=274'
# promotion_last_5years
# 0
# NO
# 1
# average_montly_hours
# '<=139'
# satisfaction_level
# '<=0.79'
# YES
# '>0.79'
# NO
# '>139'
# NO
# '>274'
# last_evaluation
# '>0.51'
# YES
# '<=0.51'
# NO
# 'product_mng'
# NO
# 'technical'
# time_spend_company
# '>3'
# last_evaluation
# '>0.59'
# average_montly_hours
# '<=182'
# average_montly_hours
# '>178'
# last_evaluation
# '>0.74'
# NO
# '<=0.74'
# YES
# '<=178'
# last_evaluation
# '<=0.89'
# NO
# '>0.89'
# last_evaluation
# '<=0.93'
# YES
# '>0.93'
# NO
# '>182'
# promotion_last_5years
# 0
# number_project
# '>4'
# last_evaluation
# '<=0.83'
# satisfaction_level
# '>0.51'
# satisfaction_level
# '<=0.89'
# NO
# '>0.89'
# satisfaction_level
# '<=0.9'
# YES
# '>0.9'
# NO
# '<=0.51'
# YES
# '>0.83'
# NO
# '<=4'
# NO
# '<=0.59'
# NO
# '<=3'
# average_montly_hours
# '>134'
# average_montly_hours
# '<=262'
# NO
# '>262'
# average_montly_hours
# '<=263'
# Work_accident
# 0
# satisfaction_level
# '>0.7'
# YES
# '<=0.7'
# NO
# 1
# NO
# '>263'
# NO
# '<=134'
# satisfaction_level
# '>0.51'
# NO
# '<=0.51'
# satisfaction_level
# '>0.48'
# YES
# '<=0.48'
# NO
# 'marketing'
# time_spend_company
# '>3'
# number_project
# '>4'
# last_evaluation
# '>0.7'
# YES
# '<=0.7'
# NO
# '<=4'
# NO
# '<=3'
# NO
# 'support'
# satisfaction_level
# '>0.5'
# time_spend_company
# '<=2'
# number_project
# '>3'
# NO
# '<=3'
# satisfaction_level
# '>0.59'
# promotion_last_5years
# 0
# satisfaction_level
# '>0.63'
# salary
# 'high'
# NO
# 'medium'
# satisfaction_level
# '<=0.83'
# NO
# '>0.83'
# satisfaction_level
# '<=0.89'
# last_evaluation
# '<=0.79'
# last_evaluation
# '>0.68'
# YES
# '<=0.68'
# satisfaction_level
# '>0.85'
# NO
# '<=0.85'
# last_evaluation
# '>0.58'
# NO
# '<=0.58'
# YES
# '>0.79'
# NO
# '>0.89'
# NO
# 'low'
# NO
# '<=0.63'
# last_evaluation
# '<=0.8'
# NO
# '>0.8'
# satisfaction_level
# '>0.61'
# YES
# '<=0.61'
# last_evaluation
# '>0.85'
# NO
# '<=0.85'
# YES
# '<=0.59'
# NO
# '>2'
# Work_accident
# 0
# NO
# 1
# promotion_last_5years
# 0
# time_spend_company
# '>3'
# average_montly_hours
# '>229'
# satisfaction_level
# '>0.7'
# YES
# '<=0.7'
# NO
# '<=229'
# NO
# '<=3'
# NO
# '<=0.5'
# promotion_last_5years
# 0
# salary
# 'high'
# NO
# 'medium'
# NO
# 'low'
# number_project
# '>4'
# satisfaction_level
# '>0.49'
# YES
# '<=0.49'
# NO
# '<=4'
# last_evaluation
# '>0.69'
# last_evaluation
# '>0.73'
# NO
# '<=0.73'
# YES
# '<=0.69'
# NO
# 'sales'
# satisfaction_level
# '<=0.8'
# satisfaction_level
# '>0.77'
# number_project
# '>3'
# last_evaluation
# '<=0.45'
# YES
# '>0.45'
# NO
# '<=3'
# promotion_last_5years
# 0
# average_montly_hours
# '>253'
# last_evaluation
# '<=0.75'
# YES
# '>0.75'
# NO
# '<=253'
# satisfaction_level
# '<=0.78'
# average_montly_hours
# '<=164'
# YES
# '>164'
# last_evaluation
# '>0.6'
# last_evaluation
# '<=0.81'
# YES
# '>0.81'
# NO
# '<=0.6'
# NO
# '>0.78'
# NO
# '<=0.77'
# satisfaction_level
# '<=0.62'
# last_evaluation
# '<=0.89'
# last_evaluation
# '>0.87'
# promotion_last_5years
# 0
# average_montly_hours
# '<=131'
# YES
# '>131'
# satisfaction_level
# '>0.48'
# NO
# '<=0.48'
# last_evaluation
# '<=0.88'
# YES
# '>0.88'
# NO
# '<=0.87'
# number_project
# '>3'
# average_montly_hours
# '>163'
# average_montly_hours
# '<=164'
# satisfaction_level
# '<=0.54'
# YES
# '>0.54'
# NO
# '>164'
# satisfaction_level
# '<=0.47'
# YES
# '>0.47'
# last_evaluation
# '<=0.46'
# YES
# '>0.46'
# salary
# 'high'
# NO
# 'medium'
# average_montly_hours
# '<=218'
# NO
# '>218'
# satisfaction_level
# '>0.53'
# promotion_last_5years
# 0
# satisfaction_level
# '<=0.57'
# average_montly_hours
# '<=236'
# YES
# '>236'
# satisfaction_level
# '<=0.54'
# YES
# '>0.54'
# NO
# '>0.57'
# NO
# '<=0.53'
# NO
# 'low'
# NO
# '<=163'
# NO
# '<=3'
# NO
# '>0.89'
# NO
# '>0.62'
# last_evaluation
# '<=0.54'
# promotion_last_5years
# 0
# last_evaluation
# '>0.53'
# salary
# 'medium'
# NO
# 'low'
# satisfaction_level
# '>0.68'
# YES
# '<=0.68'
# NO
# '<=0.53'
# NO
# '>0.54'
# NO
# '>0.8'
# NO
# 'RandD'
# satisfaction_level
# '<=0.47'
# last_evaluation
# '>0.53'
# YES
# '<=0.53'
# NO
# '>0.47'
# NO
# 'IT'
# NO
# 'hr'
# time_spend_company
# '>3'
# last_evaluation
# '<=0.83'
# NO
# '>0.83'
# Work_accident
# 0
# promotion_last_5years
# 0
# last_evaluation
# '<=0.88'
# satisfaction_level
# '>0.76'
# NO
# '<=0.76'
# satisfaction_level
# '>0.51'
# YES
# '<=0.51'
# NO
# '>0.88'
# NO
# '<=3'
# satisfaction_level
# '>0.63'
# NO
# '<=0.63'
# satisfaction_level
# '<=0.57'
# NO
# '>0.57'
# last_evaluation
# '>0.61'
# promotion_last_5years
# 0
# last_evaluation
# '<=0.62'
# number_project
# '>4'
# NO
# '<=4'
# YES
# '>0.62'
# last_evaluation
# '<=0.9'
# NO
# '>0.9'
# satisfaction_level
# '<=0.62'
# NO
# '>0.62'
# YES
# '<=0.61'
# NO
# 'accounting'
# average_montly_hours
# '<=156'
# promotion_last_5years
# 0
# satisfaction_level
# '>0.59'
# NO
# '<=0.59'
# last_evaluation
# '>0.96'
# YES
# '<=0.96'
# satisfaction_level
# '>0.5'
# NO
# '<=0.5'
# Work_accident
# 0
# satisfaction_level
# '>0.49'
# last_evaluation
# '>0.61'
# YES
# '<=0.61'
# NO
# '<=0.49'
# NO
# '>156'
# NO
# '>5'
# sales
# 'management'
# last_evaluation
# '>0.59'
# YES
# '<=0.59'
# NO
# 'product_mng'
# NO
# 'hr'
# NO
# 'marketing'
# satisfaction_level
# '>0.53'
# NO
# '<=0.53'
# YES
# 'support'
# average_montly_hours
# '>134'
# NO
# '<=134'
# average_montly_hours
# '<=130'
# NO
# '>130'
# YES
# 'sales'
# promotion_last_5years
# 0
# time_spend_company
# '<=2'
# satisfaction_level
# '>0.73'
# NO
# '<=0.73'
# last_evaluation
# '<=0.89'
# NO
# '>0.89'
# YES
# '>2'
# NO
# 'RandD'
# NO
# 'IT'
# promotion_last_5years
# 0
# average_montly_hours
# '>161'
# NO
# '<=161'
# satisfaction_level
# '<=0.66'
# NO
# '>0.66'
# YES
# 'technical'
# Work_accident
# 0
# satisfaction_level
# '>0.7'
# NO
# '<=0.7'
# promotion_last_5years
# 0
# number_project
# '>6'
# YES
# '<=6'
# salary
# 'medium'
# NO
# 'low'
# last_evaluation
# '>0.84'
# NO
# '<=0.84'
# YES
# 'accounting'
# NO

# %%
def predict(row,tree):
#     global tp,tn,fp,fn
    if tree.val=="YES" or tree.val=="NO":
        return tree.val
    
    attr=row[tree.val]
    
    if tree.val in numerical_attributes:
        if attr<=tree.spl_pt:
            x="<="+str(tree.spl_pt)
            return predict(row,tree.child[x])
        else:
            x=">"+str(tree.spl_pt)
            return predict(row,tree.child[x])
    else:
        if attr in tree.child:
            return predict(row,tree.child[attr])
    return "NO"

def calc_measures(df,tree):
    tp=0
    tn=0
    fp=0
    fn=0
    i=0
    while i< len(df):
        pred_val=predict(df.iloc[i],tree)
        if df.iloc[i]['left']==1:
            if pred_val=="YES":
                tp=tp+1
            else:
                fn=fn+1 #### fn here 
        elif df.iloc[i]['left']==0:
            if pred_val=="NO":
                tn=tn+1
            else:
                fp=fp+1 #### fp here
        i=i+1
#         print"i="
    return tp,fp,tn,fn
    
        

tp,fp,tn,fn=calc_measures(validate,tree_e)
print 'For entropy:-'
print "tp=",tp
print "tn=",tn
print "false positive=",fp
print "False negative=",fn
total=tp+tn+fp+fn
prec=tp/float(tp+fp)
rec=tp/float(tp+fn)
den=float((1/rec)+(1/prec))
f1=2/float(den)

print "Precision: ", prec
print "Recall: ",rec
print "F1: ",f1
print "accuracy: ",(tp+tn)/float(total)
# Out:
# For entropy:-
# tp= 542
# tn= 1660
# false positive= 29
# False negative= 17
# Precision:  0.949211908932
# Recall:  0.969588550984
# F1:  0.959292035398
# accuracy:  0.979537366548

# %% [markdown]
# ## For Gini Index :

# %%
def find_gini(df):
    Class = 'left'   #To make the code generic, changing target variable class name
    entropy = 1
    values = df['left'].unique()
    for value in values:
        fraction = df['left'].value_counts()[value]/float(len(df[Class]))
        entropy *= fraction
    
    return (entropy*2)

# print find_gini(df)
#satisfac ka attri gini=0.57119

# %%
#gini of categorical
def find_gini_attribute(df,attribute):
    Class = 'left'   #To make the code generic, changing target variable class name
    target_variables = df[Class].unique()  #This gives all 'Yes' and 'No'
    variables = df[attribute].unique()    #This gives different features in that attribute (like 'Hot','Cold' in Temperature)
    if len(target_variables) == 1 or len(variables) == 1:
        return 0;
    tot_gini = 0
    for variable in variables:
        entropy = 1
        num = len(df[attribute][df[attribute]==variable][df[Class] ==1])
        den= len(df[attribute][df[attribute]==variable])
        fraction = num/(den+eps)
        entropy *= fraction
        entropy*=float(1-fraction)
        entropy_fin=2*entropy
#         print entropy_fin
        x=den/float(len(df))
#         print(len(df))
        tot_gini +=entropy_fin*x
    return tot_gini

# print find_gini_attribute(df,'promotion_last_5years')

#0.36 promotion_last_5years

# %%
#numerical attributes gini
def min_num_gini(df,attribute):
    variables = df[attribute].unique()    #This gives different features in that attribute (like 'Hot','Cold' in Temperature)
    entropy2 = 0
    entropy1 = 0
    min_entr=sys.maxint
    min_split=sys.maxint
    entropy_fin=0
    for variable in variables:
        entropy = 0
        df1 = df[df[attribute]<=variable]
        df2 = df[df[attribute]>variable]
        entropy1 = find_gini(df1)
        entropy2 = find_gini(df2)
        
        fraction2 = len(df2)/float(len(df))
        fraction1 = len(df1)/float(len(df))
        entropy_fin = fraction1*entropy1+ fraction2*entropy2
        
        if min_entr>entropy_fin:
            min_entr=entropy_fin
            min_split=variable

    return min_entr,min_split
 
    
print min_num_gini(df,'satisfaction_level')    
# (0.25830236086082164, 0.46000000000000002)
# Out:
# (0.25830236086082164, 0.46000000000000002)

# %%
def max_IG_gi(dataf):    
    IG = []
    i=0
    split=-1
    max_=0
    max_in=None
    #categ
    for key in dataf.keys()[5:-1]:
        if key!= 'left':
            temp_en = find_gini_attribute(dataf,key) 
#             print temp_en
            ig1= find_gini(dataf)-temp_en      
#             print("IG 1: ",ig1,key)        
            if ig1>max_:
                max_=ig1
                max_in=key
            IG.append(ig1)

    #continuous
    for key in dataf.keys()[0:5]:
        temp_en = min_num_gini(dataf,key)[0]
        ig1=find_gini(dataf)-temp_en    
#         print("IG 2conti: ",ig1,key)        
        if ig1>max_:
            max_=ig1
            max_in=key
            split=min_num_gini(dataf,key)[1]      

        IG.append(ig1)
#     print 'ig=',IG
    return max_in,max_,split,IG

# max_IG(df)
# print max_IG(train)

# %%
class DTree:
    def __init__(self,pos=0,neg=0, child={},val = None,spl_pt=-1):
        self.val = val
        self.child = child
        self.pos=pos
        self.neg=neg
        self.spl_pt=spl_pt
        

def buildTree_gi(df1,label_node,tree=None):
    max_ig_node,gn,split,Info_gain_array = max_IG_gi(df1)
#     print max_ig_node,gn,split
#     dd=find_entropy_attribute(df1,label_node)
#     print 'MAX IG= ',gn,'split=',split
#     pprint.pprint(max_ig_node)

    c_pos=0
    c_len=0
    
    
    if gn <= 0.000001 or len(df1.columns)==1:
#         print 'IG-array',Info_gain_array
           ########switched 0 and 1
        c_pos=len(df1[df1[label_node]==1])
        c_len=len(df1[df1[label_node]==0])
        if c_pos>c_len:
            max_ig_node="YES"
        else:
            max_ig_node="NO"
        child={}
#         print "leaf nnode hai"
        leaf_n=DTree(c_pos,c_len,child,max_ig_node)
        return leaf_n

    print 'node is--- ',max_ig_node
    c_pos=len(df1[max_ig_node][df1[label_node]==1])
    c_len=len(df1[max_ig_node][df1[label_node]==0])
    child={}
    
    
    
    if split==-1:
        newnode=DTree(c_pos,c_len,child,max_ig_node,-1)
        attr = df1[max_ig_node].unique()
      
        for labels in attr:
            nd1=df1[df1[max_ig_node]==labels]
            nd1=nd1.drop(columns=[max_ig_node])
            newnode.spl_pt=-1
            newnode.child[labels] = buildTree_gi(nd1,label_node) #Calling the function recursively 

    else:
        newnode=DTree(c_pos,c_len,child,max_ig_node,split)
        label1="<="+str(split)
        label2=">"+str(split)   
#         print "numericl ka bno"
        nd1=df1[df1[max_ig_node]<=split]
        nd2=df1[df1[max_ig_node]>split]
#         print len(nd1)
#         print len(nd2)
        if len(nd1)==0 or len(nd2)==0:
            c_pos=len(df1[df1[label_node]==1])
            c_len=len(df1[df1[label_node]==0])
            if c_pos>c_len:
                max_ig_node="YES"
            else:
                max_ig_node="NO"
            child={}
#             print "leaf nnode hai"
            leaf_n=DTree(c_pos,c_len,child,max_ig_node)
            return leaf_n
#         if len(nd2
        newnode.child[label1] = buildTree_gi(nd1,label_node) #Calling the function recursively 
        newnode.child[label2] = buildTree_gi(nd2,label_node) #Calling the function recursively 
    return newnode

# %%
def traverse(tree):
    print(tree.val,'split=',tree.spl_pt)
    if tree.val==1:
        return
    for k,vals in tree.child.items():
        pprint.pprint(k)
        traverse(vals)
    
tree_g = buildTree_gi(train,'left')
pprint.pprint("tree")

traverse(tree_g)
# pprint.pprint(tree.val)
# Out:
# node is---  satisfaction_level
# node is---  number_project
# node is---  average_montly_hours
# node is---  last_evaluation
# node is---  satisfaction_level
# node is---  promotion_last_5years
# node is---  sales
# node is---  Work_accident
# node is---  salary
# node is---  salary
# node is---  Work_accident
# node is---  salary
# node is---  Work_accident
# node is---  salary
# node is---  Work_accident
# node is---  salary
# node is---  Work_accident
# node is---  salary
# node is---  salary
# node is---  Work_accident
# node is---  salary
# node is---  average_montly_hours
# node is---  Work_accident
# node is---  promotion_last_5years
# node is---  sales
# node is---  salary
# node is---  salary
# node is---  salary
# node is---  salary
# node is---  salary
# node is---  salary
# node is---  last_evaluation
# node is---  salary
# node is---  sales
# node is---  Work_accident
# node is---  promotion_last_5years
# node is---  Work_accident
# node is---  promotion_last_5years
# node is---  Work_accident
# node is---  promotion_last_5years
# node is---  Work_accident
# node is---  promotion_last_5years
# node is---  Work_accident
# node is---  promotion_last_5years
# node is---  Work_accident
# node is---  promotion_last_5years
# node is---  promotion_last_5years
# node is---  Work_accident
# node is---  promotion_last_5years
# node is---  sales
# node is---  sales
# node is---  promotion_last_5years
# node is---  satisfaction_level
# node is---  Work_accident
# node is---  average_montly_hours
# node is---  sales
# node is---  sales
# node is---  sales
# node is---  Work_accident
# node is---  Work_accident
# node is---  Work_accident
# node is---  Work_accident
# node is---  Work_accident
# node is---  salary
# node is---  sales
# node is---  Work_accident
# node is---  promotion_last_5years
# node is---  Work_accident
# node is---  promotion_last_5years
# node is---  Work_accident
# node is---  promotion_last_5years
# node is---  promotion_last_5years
# node is---  Work_accident
# node is---  promotion_last_5years
# node is---  Work_accident
# node is---  promotion_last_5years
# node is---  promotion_last_5years
# node is---  Work_accident
# node is---  promotion_last_5years
# node is---  promotion_last_5years
# node is---  Work_accident
# node is---  promotion_last_5years
# node is---  promotion_last_5years
# node is---  Work_accident
# node is---  promotion_last_5years
# node is---  promotion_last_5years
# node is---  Work_accident
# node is---  promotion_last_5years
# node is---  Work_accident
# node is---  promotion_last_5years
# node is---  promotion_last_5years
# node is---  Work_accident
# node is---  promotion_last_5years
# node is---  sales
# node is---  sales
# node is---  promotion_last_5years
# node is---  sales
# node is---  Work_accident
# node is---  promotion_last_5years
# node is---  sales
# node is---  promotion_last_5years
# node is---  sales
# node is---  Work_accident
# node is---  salary
# node is---  salary
# node is---  Work_accident
# node is---  salary
# node is---  salary
# node is---  Work_accident
# node is---  Work_accident
# node is---  Work_accident
# node is---  Work_accident
# node is---  salary
# node is---  Work_accident
# node is---  salary
# node is---  Work_accident
# node is---  salary
# node is---  Work_accident
# node is---  salary
# node is---  Work_accident
# node is---  salary
# node is---  promotion_last_5years
# node is---  satisfaction_level
# node is---  Work_accident
# node is---  sales
# node is---  salary
# node is---  salary
# node is---  average_montly_hours
# node is---  sales
# node is---  Work_accident
# node is---  salary
# node is---  salary
# node is---  salary
# node is---  Work_accident
# node is---  Work_accident
# node is---  Work_accident
# node is---  Work_accident
# node is---  salary
# node is---  Work_accident
# node is---  salary
# node is---  salary
# node is---  Work_accident
# node is---  salary
# node is---  salary
# node is---  Work_accident
# node is---  salary
# node is---  salary
# node is---  Work_accident
# node is---  salary
# node is---  salary
# node is---  Work_accident
# node is---  salary
# node is---  salary
# node is---  Work_accident
# node is---  salary
# node is---  Work_accident
# node is---  salary
# node is---  Work_accident
# node is---  sales
# node is---  salary
# node is---  salary
# node is---  salary
# node is---  satisfaction_level
# node is---  last_evaluation
# node is---  Work_accident
# node is---  promotion_last_5years
# node is---  sales
# node is---  salary
# node is---  salary
# node is---  salary
# node is---  salary
# node is---  salary
# node is---  salary
# node is---  average_montly_hours
# node is---  Work_accident
# node is---  promotion_last_5years
# node is---  sales
# node is---  salary
# node is---  salary
# node is---  salary
# node is---  salary
# node is---  sales
# node is---  Work_accident
# node is---  promotion_last_5years
# node is---  salary
# node is---  promotion_last_5years
# node is---  salary
# node is---  Work_accident
# node is---  promotion_last_5years
# node is---  salary
# node is---  salary
# node is---  promotion_last_5years
# node is---  salary
# node is---  Work_accident
# node is---  promotion_last_5years
# node is---  salary
# node is---  promotion_last_5years
# node is---  salary
# node is---  Work_accident
# node is---  promotion_last_5years
# node is---  salary
# node is---  promotion_last_5years
# node is---  salary
# node is---  Work_accident
# node is---  promotion_last_5years
# node is---  salary
# node is---  Work_accident
# node is---  promotion_last_5years
# node is---  salary
# node is---  promotion_last_5years
# node is---  salary
# node is---  Work_accident
# node is---  promotion_last_5years
# node is---  salary
# node is---  Work_accident
# node is---  promotion_last_5years
# node is---  salary
# node is---  promotion_last_5years
# node is---  Work_accident
# node is---  salary
# node is---  salary
# node is---  Work_accident
# node is---  promotion_last_5years
# node is---  salary
# node is---  number_project
# node is---  sales
# node is---  promotion_last_5years
# node is---  last_evaluation
# node is---  salary
# node is---  Work_accident
# node is---  Work_accident
# node is---  Work_accident
# node is---  salary
# node is---  Work_accident
# node is---  salary
# node is---  promotion_last_5years
# node is---  Work_accident
# node is---  Work_accident
# node is---  promotion_last_5years
# node is---  promotion_last_5years
# node is---  Work_accident
# node is---  promotion_last_5years
# node is---  promotion_last_5years
# node is---  Work_accident
# node is---  promotion_last_5years
# node is---  salary
# node is---  promotion_last_5years
# node is---  salary
# node is---  salary
# node is---  Work_accident
# node is---  promotion_last_5years
# node is---  promotion_last_5years
# node is---  Work_accident
# node is---  promotion_last_5years
# node is---  Work_accident
# node is---  promotion_last_5years
# node is---  satisfaction_level
# node is---  promotion_last_5years
# node is---  average_montly_hours
# node is---  last_evaluation
# node is---  salary
# node is---  Work_accident
# node is---  Work_accident
# node is---  Work_accident
# node is---  salary
# node is---  Work_accident
# node is---  Work_accident
# node is---  Work_accident
# node is---  Work_accident
# node is---  salary
# node is---  salary
# node is---  satisfaction_level
# node is---  promotion_last_5years
# node is---  salary
# node is---  Work_accident
# node is---  Work_accident
# node is---  Work_accident
# node is---  average_montly_hours
# node is---  salary
# node is---  Work_accident
# node is---  promotion_last_5years
# node is---  promotion_last_5years
# node is---  promotion_last_5years
# node is---  Work_accident
# node is---  Work_accident
# node is---  promotion_last_5years
# node is---  promotion_last_5years
# node is---  promotion_last_5years
# node is---  number_project
# node is---  Work_accident
# node is---  salary
# node is---  Work_accident
# node is---  salary
# node is---  salary
# node is---  Work_accident
# node is---  promotion_last_5years
# node is---  salary
# node is---  promotion_last_5years
# node is---  salary
# node is---  promotion_last_5years
# node is---  average_montly_hours
# node is---  Work_accident
# node is---  salary
# node is---  salary
# node is---  last_evaluation
# node is---  Work_accident
# node is---  salary
# node is---  satisfaction_level
# node is---  average_montly_hours
# node is---  Work_accident
# node is---  salary
# node is---  salary
# node is---  salary
# node is---  Work_accident
# node is---  Work_accident
# node is---  Work_accident
# node is---  last_evaluation
# node is---  average_montly_hours
# node is---  salary
# node is---  Work_accident
# node is---  promotion_last_5years
# node is---  promotion_last_5years
# node is---  Work_accident
# node is---  promotion_last_5years
# node is---  Work_accident
# node is---  promotion_last_5years
# node is---  promotion_last_5years
# node is---  promotion_last_5years
# node is---  Work_accident
# node is---  salary
# node is---  salary
# node is---  promotion_last_5years
# node is---  salary
# node is---  Work_accident
# node is---  satisfaction_level
# node is---  Work_accident
# node is---  promotion_last_5years
# node is---  salary
# node is---  average_montly_hours
# node is---  promotion_last_5years
# node is---  Work_accident
# node is---  salary
# node is---  salary
# node is---  salary
# node is---  Work_accident
# node is---  promotion_last_5years
# node is---  promotion_last_5years
# node is---  Work_accident
# node is---  promotion_last_5years
# node is---  promotion_last_5years
# node is---  Work_accident
# node is---  promotion_last_5years
# node is---  promotion_last_5years
# node is---  Work_accident
# node is---  promotion_last_5years
# node is---  salary
# node is---  promotion_last_5years
# node is---  salary
# node is---  sales
# node is---  average_montly_hours
# node is---  salary
# node is---  Work_accident
# node is---  promotion_last_5years
# node is---  promotion_last_5years
# node is---  Work_accident
# node is---  promotion_last_5years
# node is---  promotion_last_5years
# node is---  promotion_last_5years
# node is---  Work_accident
# node is---  salary
# node is---  Work_accident
# node is---  promotion_last_5years
# node is---  promotion_last_5years
# node is---  Work_accident
# node is---  promotion_last_5years
# node is---  satisfaction_level
# node is---  Work_accident
# node is---  promotion_last_5years
# node is---  salary
# node is---  promotion_last_5years
# node is---  salary
# node is---  promotion_last_5years
# node is---  Work_accident
# node is---  satisfaction_level
# node is---  salary
# node is---  salary
# node is---  salary
# node is---  promotion_last_5years
# node is---  salary
# node is---  Work_accident
# node is---  Work_accident
# node is---  satisfaction_level
# node is---  Work_accident
# node is---  Work_accident
# node is---  promotion_last_5years
# node is---  average_montly_hours
# node is---  salary
# node is---  Work_accident
# node is---  Work_accident
# node is---  salary
# node is---  Work_accident
# node is---  Work_accident
# node is---  Work_accident
# node is---  promotion_last_5years
# node is---  Work_accident
# node is---  salary
# node is---  salary
# node is---  Work_accident
# node is---  promotion_last_5years
# node is---  salary
# node is---  Work_accident
# node is---  salary
# node is---  promotion_last_5years
# node is---  promotion_last_5years
# node is---  promotion_last_5years
# node is---  Work_accident
# node is---  promotion_last_5years
# node is---  salary
# node is---  Work_accident
# node is---  promotion_last_5years
# node is---  salary
# node is---  promotion_last_5years
# node is---  salary
# node is---  time_spend_company
# node is---  average_montly_hours
# node is---  number_project
# node is---  number_project
# node is---  average_montly_hours
# node is---  last_evaluation
# node is---  sales
# node is---  Work_accident
# node is---  promotion_last_5years
# node is---  salary
# node is---  promotion_last_5years
# node is---  salary
# node is---  Work_accident
# node is---  promotion_last_5years
# node is---  salary
# node is---  promotion_last_5years
# node is---  salary
# node is---  Work_accident
# node is---  promotion_last_5years
# node is---  salary
# node is---  salary
# node is---  promotion_last_5years
# node is---  salary
# node is---  Work_accident
# node is---  promotion_last_5years
# node is---  salary
# node is---  salary
# node is---  promotion_last_5years
# node is---  salary
# node is---  Work_accident
# node is---  promotion_last_5years
# node is---  salary
# node is---  promotion_last_5years
# node is---  salary
# node is---  Work_accident
# node is---  promotion_last_5years
# node is---  salary
# node is---  promotion_last_5years
# node is---  salary
# node is---  Work_accident
# node is---  promotion_last_5years
# node is---  salary
# node is---  promotion_last_5years
# node is---  salary
# node is---  Work_accident
# node is---  promotion_last_5years
# node is---  salary
# node is---  promotion_last_5years
# node is---  salary
# node is---  promotion_last_5years
# node is---  salary
# node is---  Work_accident
# node is---  Work_accident
# node is---  Work_accident
# node is---  Work_accident
# node is---  promotion_last_5years
# node is---  salary
# node is---  promotion_last_5years
# node is---  salary
# node is---  last_evaluation
# node is---  Work_accident
# node is---  promotion_last_5years
# node is---  sales
# node is---  salary
# node is---  salary
# node is---  salary
# node is---  sales
# node is---  Work_accident
# node is---  promotion_last_5years
# node is---  salary
# node is---  salary
# node is---  Work_accident
# node is---  promotion_last_5years
# node is---  promotion_last_5years
# node is---  Work_accident
# node is---  promotion_last_5years
# node is---  promotion_last_5years
# node is---  Work_accident
# node is---  promotion_last_5years
# node is---  Work_accident
# node is---  promotion_last_5years
# node is---  salary
# node is---  promotion_last_5years
# node is---  salary
# node is---  Work_accident
# node is---  promotion_last_5years
# node is---  salary
# node is---  promotion_last_5years
# node is---  salary
# node is---  Work_accident
# node is---  promotion_last_5years
# node is---  salary
# node is---  Work_accident
# node is---  promotion_last_5years
# node is---  salary
# node is---  promotion_last_5years
# node is---  salary
# node is---  promotion_last_5years
# node is---  salary
# node is---  Work_accident
# node is---  Work_accident
# node is---  Work_accident
# node is---  Work_accident
# node is---  promotion_last_5years
# node is---  salary
# node is---  promotion_last_5years
# node is---  salary
# node is---  Work_accident
# node is---  promotion_last_5years
# node is---  salary
# node is---  Work_accident
# node is---  promotion_last_5years
# node is---  salary
# node is---  promotion_last_5years
# node is---  sales
# node is---  last_evaluation
# node is---  Work_accident
# node is---  salary
# node is---  salary
# node is---  Work_accident
# node is---  Work_accident
# node is---  Work_accident
# node is---  Work_accident
# node is---  salary
# node is---  salary
# node is---  Work_accident
# node is---  salary
# node is---  Work_accident
# node is---  salary
# node is---  Work_accident
# node is---  salary
# node is---  Work_accident
# node is---  salary
# node is---  Work_accident
# node is---  salary
# node is---  salary
# node is---  Work_accident
# node is---  salary
# node is---  Work_accident
# node is---  salary
# node is---  time_spend_company
# node is---  sales
# node is---  satisfaction_level
# node is---  satisfaction_level
# node is---  salary
# node is---  Work_accident
# node is---  promotion_last_5years
# node is---  promotion_last_5years
# node is---  Work_accident
# node is---  promotion_last_5years
# node is---  promotion_last_5years
# node is---  promotion_last_5years
# node is---  Work_accident
# node is---  satisfaction_level
# node is---  promotion_last_5years
# node is---  last_evaluation
# node is---  Work_accident
# node is---  salary
# node is---  Work_accident
# node is---  salary
# node is---  salary
# node is---  salary
# node is---  Work_accident
# node is---  promotion_last_5years
# node is---  promotion_last_5years
# node is---  Work_accident
# node is---  promotion_last_5years
# node is---  promotion_last_5years
# node is---  Work_accident
# node is---  promotion_last_5years
# node is---  last_evaluation
# node is---  promotion_last_5years
# node is---  salary
# node is---  Work_accident
# node is---  Work_accident
# node is---  Work_accident
# node is---  average_montly_hours
# node is---  salary
# node is---  average_montly_hours
# node is---  Work_accident
# node is---  promotion_last_5years
# node is---  promotion_last_5years
# node is---  average_montly_hours
# node is---  Work_accident
# node is---  Work_accident
# node is---  Work_accident
# node is---  promotion_last_5years
# node is---  promotion_last_5years
# node is---  Work_accident
# node is---  promotion_last_5years
# node is---  promotion_last_5years
# node is---  salary
# node is---  Work_accident
# node is---  promotion_last_5years
# node is---  promotion_last_5years
# node is---  Work_accident
# node is---  promotion_last_5years
# node is---  promotion_last_5years
# node is---  Work_accident
# node is---  promotion_last_5years
# node is---  salary
# node is---  Work_accident
# node is---  promotion_last_5years
# node is---  promotion_last_5years
# node is---  Work_accident
# node is---  promotion_last_5years
# node is---  promotion_last_5years
# node is---  Work_accident
# node is---  promotion_last_5years
# node is---  promotion_last_5years
# node is---  salary
# node is---  Work_accident
# node is---  promotion_last_5years
# node is---  promotion_last_5years
# node is---  Work_accident
# node is---  promotion_last_5years
# node is---  promotion_last_5years
# node is---  Work_accident
# node is---  promotion_last_5years
# node is---  promotion_last_5years
# node is---  satisfaction_level
# node is---  promotion_last_5years
# node is---  salary
# node is---  Work_accident
# node is---  Work_accident
# node is---  Work_accident
# node is---  last_evaluation
# node is---  salary
# node is---  Work_accident
# node is---  promotion_last_5years
# node is---  promotion_last_5years
# node is---  Work_accident
# node is---  promotion_last_5years
# node is---  promotion_last_5years
# node is---  Work_accident
# node is---  promotion_last_5years
# node is---  promotion_last_5years
# node is---  last_evaluation
# node is---  salary
# node is---  promotion_last_5years
# node is---  Work_accident
# node is---  Work_accident
# node is---  Work_accident
# node is---  promotion_last_5years
# node is---  Work_accident
# node is---  promotion_last_5years
# node is---  promotion_last_5years
# node is---  average_montly_hours
# node is---  salary
# node is---  Work_accident
# node is---  promotion_last_5years
# node is---  promotion_last_5years
# node is---  promotion_last_5years
# node is---  Work_accident
# node is---  Work_accident
# node is---  promotion_last_5years
# node is---  promotion_last_5years
# node is---  promotion_last_5years
# node is---  salary
# node is---  Work_accident
# node is---  Work_accident
# node is---  Work_accident
# node is---  average_montly_hours
# node is---  salary
# node is---  promotion_last_5years
# node is---  Work_accident
# node is---  Work_accident
# node is---  promotion_last_5years
# node is---  Work_accident
# node is---  promotion_last_5years
# node is---  salary
# node is---  Work_accident
# node is---  promotion_last_5years
# node is---  promotion_last_5years
# node is---  Work_accident
# node is---  promotion_last_5years
# node is---  Work_accident
# node is---  promotion_last_5years
# node is---  promotion_last_5years
# node is---  Work_accident
# node is---  promotion_last_5years
# node is---  salary
# node is---  salary
# node is---  promotion_last_5years
# node is---  salary
# node is---  salary
# node is---  Work_accident
# node is---  promotion_last_5years
# node is---  salary
# node is---  promotion_last_5years
# node is---  salary
# node is---  average_montly_hours
# node is---  promotion_last_5years
# node is---  Work_accident
# node is---  salary
# node is---  salary
# node is---  salary
# node is---  Work_accident
# node is---  Work_accident
# node is---  Work_accident
# node is---  Work_accident
# node is---  promotion_last_5years
# node is---  salary
# node is---  Work_accident
# node is---  promotion_last_5years
# node is---  salary
# node is---  promotion_last_5years
# node is---  salary
# node is---  satisfaction_level
# node is---  promotion_last_5years
# node is---  salary
# node is---  Work_accident
# node is---  Work_accident
# node is---  Work_accident
# node is---  salary
# node is---  promotion_last_5years
# node is---  Work_accident
# node is---  Work_accident
# node is---  promotion_last_5years
# node is---  promotion_last_5years
# node is---  Work_accident
# node is---  promotion_last_5years
# node is---  promotion_last_5years
# node is---  sales
# node is---  satisfaction_level
# node is---  Work_accident
# node is---  promotion_last_5years
# node is---  salary
# node is---  last_evaluation
# node is---  Work_accident
# node is---  promotion_last_5years
# node is---  salary
# node is---  salary
# node is---  Work_accident
# node is---  promotion_last_5years
# node is---  promotion_last_5years
# node is---  promotion_last_5years
# node is---  Work_accident
# node is---  Work_accident
# node is---  promotion_last_5years
# node is---  promotion_last_5years
# node is---  salary
# node is---  Work_accident
# node is---  promotion_last_5years
# node is---  promotion_last_5years
# node is---  promotion_last_5years
# node is---  Work_accident
# node is---  Work_accident
# node is---  promotion_last_5years
# node is---  average_montly_hours
# node is---  average_montly_hours
# node is---  salary
# node is---  Work_accident
# node is---  promotion_last_5years
# node is---  promotion_last_5years
# node is---  Work_accident
# node is---  promotion_last_5years
# node is---  promotion_last_5years
# node is---  Work_accident
# node is---  promotion_last_5years
# node is---  promotion_last_5years
# node is---  Work_accident
# node is---  promotion_last_5years
# node is---  salary
# node is---  satisfaction_level
# node is---  promotion_last_5years
# node is---  salary
# node is---  Work_accident
# node is---  Work_accident
# node is---  salary
# node is---  Work_accident
# node is---  promotion_last_5years
# node is---  promotion_last_5years
# node is---  promotion_last_5years
# node is---  Work_accident
# node is---  Work_accident
# node is---  promotion_last_5years
# node is---  Work_accident
# node is---  promotion_last_5years
# node is---  salary
# node is---  promotion_last_5years
# node is---  salary
# node is---  promotion_last_5years
# node is---  satisfaction_level
# node is---  Work_accident
# node is---  salary
# node is---  Work_accident
# node is---  salary
# node is---  salary
# node is---  Work_accident
# node is---  promotion_last_5years
# node is---  salary
# node is---  promotion_last_5years
# node is---  salary
# node is---  promotion_last_5years
# node is---  salary
# node is---  Work_accident
# node is---  Work_accident
# node is---  Work_accident
# node is---  Work_accident
# node is---  promotion_last_5years
# node is---  salary
# node is---  promotion_last_5years
# node is---  salary
# node is---  salary
# node is---  last_evaluation
# node is---  salary
# node is---  Work_accident
# node is---  promotion_last_5years
# node is---  promotion_last_5years
# node is---  Work_accident
# node is---  Work_accident
# node is---  promotion_last_5years
# node is---  promotion_last_5years
# node is---  Work_accident
# node is---  promotion_last_5years
# node is---  salary
# node is---  satisfaction_level
# node is---  Work_accident
# node is---  promotion_last_5years
# node is---  salary
# node is---  salary
# node is---  promotion_last_5years
# node is---  salary
# node is---  sales
# node is---  Work_accident
# node is---  promotion_last_5years
# node is---  salary
# node is---  promotion_last_5years
# node is---  average_montly_hours
# node is---  salary
# node is---  Work_accident
# node is---  Work_accident
# node is---  Work_accident
# node is---  Work_accident
# node is---  salary
# node is---  salary
# node is---  Work_accident
# node is---  promotion_last_5years
# node is---  Work_accident
# node is---  promotion_last_5years
# node is---  promotion_last_5years
# node is---  Work_accident
# node is---  promotion_last_5years
# node is---  promotion_last_5years
# node is---  promotion_last_5years
# node is---  satisfaction_level
# node is---  salary
# node is---  Work_accident
# node is---  Work_accident
# node is---  Work_accident
# node is---  Work_accident
# node is---  salary
# node is---  Work_accident
# node is---  promotion_last_5years
# node is---  salary
# node is---  promotion_last_5years
# node is---  salary
# node is---  Work_accident
# node is---  satisfaction_level
# node is---  promotion_last_5years
# node is---  salary
# node is---  salary
# node is---  promotion_last_5years
# node is---  promotion_last_5years
# node is---  promotion_last_5years
# node is---  Work_accident
# node is---  promotion_last_5years
# node is---  salary
# node is---  promotion_last_5years
# node is---  salary
# node is---  salary
# node is---  promotion_last_5years
# node is---  salary
# node is---  Work_accident
# node is---  Work_accident
# node is---  Work_accident
# node is---  promotion_last_5years
# node is---  salary
# node is---  promotion_last_5years
# node is---  salary
# node is---  Work_accident
# node is---  Work_accident
# node is---  Work_accident
# node is---  promotion_last_5years
# node is---  sales
# node is---  salary
# node is---  salary
# node is---  salary
# node is---  salary
# node is---  salary
# node is---  last_evaluation
# node is---  last_evaluation
# node is---  sales
# node is---  average_montly_hours
# node is---  satisfaction_level
# node is---  salary
# node is---  Work_accident
# node is---  promotion_last_5years
# node is---  promotion_last_5years
# node is---  Work_accident
# node is---  promotion_last_5years
# node is---  Work_accident
# node is---  promotion_last_5years
# node is---  promotion_last_5years
# node is---  promotion_last_5years
# node is---  Work_accident
# node is---  salary
# node is---  salary
# node is---  Work_accident
# node is---  promotion_last_5years
# node is---  salary
# node is---  Work_accident
# node is---  promotion_last_5years
# node is---  salary
# node is---  salary
# node is---  promotion_last_5years
# node is---  salary
# node is---  salary
# node is---  salary
# node is---  promotion_last_5years
# node is---  average_montly_hours
# node is---  Work_accident
# node is---  Work_accident
# node is---  Work_accident
# node is---  promotion_last_5years
# node is---  promotion_last_5years
# node is---  Work_accident
# node is---  promotion_last_5years
# node is---  promotion_last_5years
# node is---  salary
# node is---  Work_accident
# node is---  Work_accident
# node is---  Work_accident
# node is---  salary
# node is---  Work_accident
# node is---  promotion_last_5years
# node is---  promotion_last_5years
# node is---  Work_accident
# node is---  Work_accident
# node is---  promotion_last_5years
# node is---  Work_accident
# node is---  promotion_last_5years
# node is---  salary
# node is---  salary
# node is---  promotion_last_5years
# node is---  salary
# node is---  salary
# node is---  last_evaluation
# node is---  Work_accident
# node is---  promotion_last_5years
# node is---  salary
# node is---  promotion_last_5years
# node is---  salary
# node is---  salary
# node is---  promotion_last_5years
# node is---  Work_accident
# node is---  salary
# node is---  salary
# node is---  salary
# node is---  Work_accident
# node is---  promotion_last_5years
# node is---  promotion_last_5years
# node is---  promotion_last_5years
# node is---  Work_accident
# node is---  Work_accident
# node is---  promotion_last_5years
# node is---  promotion_last_5years
# node is---  Work_accident
# node is---  promotion_last_5years
# node is---  salary
# node is---  promotion_last_5years
# node is---  salary
# node is---  promotion_last_5years
# node is---  salary
# node is---  Work_accident
# node is---  Work_accident
# node is---  Work_accident
# node is---  salary
# node is---  salary
# node is---  salary
# node is---  sales
# node is---  promotion_last_5years
# node is---  Work_accident
# node is---  Work_accident
# node is---  promotion_last_5years
# node is---  Work_accident
# node is---  promotion_last_5years
# node is---  Work_accident
# node is---  promotion_last_5years
# node is---  Work_accident
# node is---  promotion_last_5years
# node is---  sales
# node is---  promotion_last_5years
# node is---  Work_accident
# node is---  sales
# node is---  sales
# node is---  average_montly_hours
# node is---  number_project
# node is---  Work_accident
# node is---  promotion_last_5years
# node is---  sales
# node is---  salary
# node is---  salary
# node is---  salary
# node is---  salary
# node is---  salary
# node is---  salary
# node is---  salary
# node is---  Work_accident
# node is---  promotion_last_5years
# node is---  sales
# node is---  sales
# node is---  promotion_last_5years
# node is---  sales
# node is---  Work_accident
# node is---  promotion_last_5years
# node is---  sales
# node is---  sales
# node is---  promotion_last_5years
# node is---  last_evaluation
# node is---  sales
# node is---  Work_accident
# node is---  Work_accident
# node is---  Work_accident
# node is---  Work_accident
# node is---  Work_accident
# node is---  Work_accident
# node is---  time_spend_company
# node is---  Work_accident
# node is---  Work_accident
# node is---  sales
# node is---  Work_accident
# node is---  Work_accident
# node is---  Work_accident
# node is---  satisfaction_level
# node is---  number_project
# node is---  Work_accident
# node is---  promotion_last_5years
# node is---  sales
# node is---  salary
# node is---  last_evaluation
# node is---  sales
# node is---  Work_accident
# node is---  salary
# node is---  promotion_last_5years
# node is---  Work_accident
# node is---  promotion_last_5years
# node is---  salary
# node is---  salary
# node is---  promotion_last_5years
# node is---  salary
# node is---  Work_accident
# node is---  promotion_last_5years
# node is---  salary
# node is---  Work_accident
# node is---  promotion_last_5years
# node is---  salary
# node is---  Work_accident
# node is---  promotion_last_5years
# node is---  salary
# node is---  promotion_last_5years
# node is---  salary
# node is---  Work_accident
# node is---  promotion_last_5years
# node is---  salary
# node is---  Work_accident
# node is---  promotion_last_5years
# node is---  salary
# node is---  Work_accident
# node is---  promotion_last_5years
# node is---  salary
# node is---  promotion_last_5years
# node is---  salary
# node is---  sales
# node is---  Work_accident
# node is---  promotion_last_5years
# node is---  salary
# node is---  Work_accident
# node is---  promotion_last_5years
# node is---  salary
# node is---  Work_accident
# node is---  promotion_last_5years
# node is---  salary
# node is---  promotion_last_5years
# node is---  Work_accident
# node is---  salary
# node is---  salary
# node is---  Work_accident
# node is---  promotion_last_5years
# node is---  salary
# node is---  Work_accident
# node is---  promotion_last_5years
# node is---  salary
# node is---  satisfaction_level
# node is---  sales
# node is---  time_spend_company
# node is---  average_montly_hours
# node is---  Work_accident
# node is---  promotion_last_5years
# node is---  salary
# node is---  salary
# node is---  Work_accident
# node is---  promotion_last_5years
# node is---  Work_accident
# node is---  promotion_last_5years
# node is---  promotion_last_5years
# node is---  Work_accident
# node is---  promotion_last_5years
# node is---  promotion_last_5years
# node is---  average_montly_hours
# node is---  Work_accident
# node is---  satisfaction_level
# node is---  salary
# node is---  salary
# node is---  salary
# node is---  salary
# node is---  Work_accident
# node is---  promotion_last_5years
# node is---  last_evaluation
# node is---  Work_accident
# node is---  salary
# node is---  Work_accident
# node is---  salary
# node is---  salary
# node is---  Work_accident
# node is---  promotion_last_5years
# node is---  salary
# node is---  promotion_last_5years
# node is---  Work_accident
# node is---  satisfaction_level
# node is---  salary
# node is---  salary
# node is---  salary
# node is---  salary
# node is---  Work_accident
# node is---  promotion_last_5years
# node is---  Work_accident
# node is---  promotion_last_5years
# node is---  Work_accident
# node is---  promotion_last_5years
# node is---  promotion_last_5years
# node is---  promotion_last_5years
# node is---  average_montly_hours
# node is---  salary
# node is---  Work_accident
# node is---  Work_accident
# node is---  Work_accident
# node is---  Work_accident
# node is---  salary
# node is---  Work_accident
# node is---  promotion_last_5years
# node is---  salary
# node is---  promotion_last_5years
# node is---  salary
# node is---  Work_accident
# node is---  promotion_last_5years
# node is---  salary
# node is---  promotion_last_5years
# node is---  salary
# node is---  Work_accident
# node is---  Work_accident
# node is---  promotion_last_5years
# node is---  salary
# node is---  Work_accident
# node is---  Work_accident
# node is---  number_project
# node is---  sales
# node is---  promotion_last_5years
# node is---  Work_accident
# node is---  salary
# node is---  salary
# node is---  Work_accident
# node is---  promotion_last_5years
# node is---  salary
# node is---  Work_accident
# node is---  promotion_last_5years
# node is---  salary
# node is---  promotion_last_5years
# node is---  salary
# node is---  Work_accident
# node is---  Work_accident
# node is---  Work_accident
# node is---  promotion_last_5years
# node is---  salary
# node is---  Work_accident
# node is---  promotion_last_5years
# node is---  salary
# node is---  Work_accident
# node is---  promotion_last_5years
# node is---  sales
# node is---  salary
# node is---  salary
# node is---  salary
# 'tree'
# ('satisfaction_level', 'split=', 0.46000000000000002)
# '<=0.46'
# ('number_project', 'split=', 2)
# '<=2'
# ('average_montly_hours', 'split=', 161)
# '>161'
# ('promotion_last_5years', 'split=', -1)
# 0
# ('satisfaction_level', 'split=', 0.12)
# '<=0.12'
# ('Work_accident', 'split=', -1)
# 0
# ('sales', 'split=', -1)
# 'technical'
# ('salary', 'split=', -1)
# 'medium'
# ('NO', 'split=', -1)
# 'sales'
# ('salary', 'split=', -1)
# 'medium'
# ('YES', 'split=', -1)
# '>0.12'
# ('average_montly_hours', 'split=', 278)
# '<=278'
# ('sales', 'split=', -1)
# 'management'
# ('Work_accident', 'split=', -1)
# 0
# ('salary', 'split=', -1)
# 'high'
# ('NO', 'split=', -1)
# 'medium'
# ('NO', 'split=', -1)
# 1
# ('salary', 'split=', -1)
# 'low'
# ('NO', 'split=', -1)
# 'product_mng'
# ('Work_accident', 'split=', -1)
# 0
# ('salary', 'split=', -1)
# 'medium'
# ('NO', 'split=', -1)
# 'low'
# ('NO', 'split=', -1)
# 'technical'
# ('Work_accident', 'split=', -1)
# 0
# ('salary', 'split=', -1)
# 'medium'
# ('NO', 'split=', -1)
# 'low'
# ('NO', 'split=', -1)
# 1
# ('salary', 'split=', -1)
# 'high'
# ('NO', 'split=', -1)
# 'marketing'
# ('Work_accident', 'split=', -1)
# 0
# ('salary', 'split=', -1)
# 'low'
# ('NO', 'split=', -1)
# 'support'
# ('Work_accident', 'split=', -1)
# 0
# ('salary', 'split=', -1)
# 'medium'
# ('NO', 'split=', -1)
# 'low'
# ('NO', 'split=', -1)
# 1
# ('salary', 'split=', -1)
# 'low'
# ('NO', 'split=', -1)
# 'IT'
# ('Work_accident', 'split=', -1)
# 0
# ('salary', 'split=', -1)
# 'medium'
# ('NO', 'split=', -1)
# 'low'
# ('NO', 'split=', -1)
# 1
# ('salary', 'split=', -1)
# 'low'
# ('NO', 'split=', -1)
# 'RandD'
# ('Work_accident', 'split=', -1)
# 0
# ('salary', 'split=', -1)
# 'medium'
# ('NO', 'split=', -1)
# 'low'
# ('NO', 'split=', -1)
# 'sales'
# ('salary', 'split=', -1)
# 'high'
# ('Work_accident', 'split=', -1)
# 0
# ('NO', 'split=', -1)
# 'medium'
# ('Work_accident', 'split=', -1)
# 0
# ('NO', 'split=', -1)
# 1
# ('NO', 'split=', -1)
# 'low'
# ('Work_accident', 'split=', -1)
# 0
# ('NO', 'split=', -1)
# 1
# ('NO', 'split=', -1)
# 'hr'
# ('Work_accident', 'split=', -1)
# 0
# ('salary', 'split=', -1)
# 'medium'
# ('NO', 'split=', -1)
# 'low'
# ('NO', 'split=', -1)
# 1
# ('salary', 'split=', -1)
# 'low'
# ('NO', 'split=', -1)
# 'accounting'
# ('Work_accident', 'split=', -1)
# 0
# ('salary', 'split=', -1)
# 'medium'
# ('NO', 'split=', -1)
# 'low'
# ('NO', 'split=', -1)
# 1
# ('salary', 'split=', -1)
# 'low'
# ('NO', 'split=', -1)
# '>278'
# ('Work_accident', 'split=', -1)
# 0
# ('sales', 'split=', -1)
# 'technical'
# ('salary', 'split=', -1)
# 'low'
# ('NO', 'split=', -1)
# 'marketing'
# ('salary', 'split=', -1)
# 'low'
# ('YES', 'split=', -1)
# 'IT'
# ('salary', 'split=', -1)
# 'medium'
# ('NO', 'split=', -1)
# '<=161'
# ('last_evaluation', 'split=', 0.56999999999999995)
# '<=0.57'
# ('satisfaction_level', 'split=', 0.34000000000000002)
# '<=0.34'
# ('promotion_last_5years', 'split=', -1)
# 0
# ('sales', 'split=', -1)
# 'technical'
# ('Work_accident', 'split=', -1)
# 0
# ('salary', 'split=', -1)
# 'high'
# ('NO', 'split=', -1)
# 'medium'
# ('NO', 'split=', -1)
# 'low'
# ('NO', 'split=', -1)
# 'support'
# ('Work_accident', 'split=', -1)
# 1
# ('salary', 'split=', -1)
# 'medium'
# ('NO', 'split=', -1)
# 'sales'
# ('Work_accident', 'split=', -1)
# 0
# ('salary', 'split=', -1)
# 'medium'
# ('NO', 'split=', -1)
# 'low'
# ('YES', 'split=', -1)
# 'RandD'
# ('Work_accident', 'split=', -1)
# 0
# ('salary', 'split=', -1)
# 'medium'
# ('NO', 'split=', -1)
# 'low'
# ('NO', 'split=', -1)
# 1
# ('salary', 'split=', -1)
# 'low'
# ('YES', 'split=', -1)
# 'hr'
# ('Work_accident', 'split=', -1)
# 0
# ('salary', 'split=', -1)
# 'medium'
# ('NO', 'split=', -1)
# 1
# ('salary', 'split=', -1)
# 'low'
# ('NO', 'split=', -1)
# 'accounting'
# ('Work_accident', 'split=', -1)
# 0
# ('salary', 'split=', -1)
# 'medium'
# ('NO', 'split=', -1)
# '>0.34'
# ('average_montly_hours', 'split=', 126)
# '>126'
# ('last_evaluation', 'split=', 0.45000000000000001)
# '<=0.45'
# ('salary', 'split=', -1)
# 'high'
# ('Work_accident', 'split=', -1)
# 1
# ('promotion_last_5years', 'split=', -1)
# 0
# ('sales', 'split=', -1)
# 'support'
# ('NO', 'split=', -1)
# 1
# ('sales', 'split=', -1)
# 'management'
# ('NO', 'split=', -1)
# 'medium'
# ('promotion_last_5years', 'split=', -1)
# 0
# ('satisfaction_level', 'split=', 0.38)
# '>0.38'
# ('sales', 'split=', -1)
# 'hr'
# ('Work_accident', 'split=', -1)
# 0
# ('YES', 'split=', -1)
# 'technical'
# ('Work_accident', 'split=', -1)
# 0
# ('YES', 'split=', -1)
# 'support'
# ('Work_accident', 'split=', -1)
# 1
# ('YES', 'split=', -1)
# 'sales'
# ('Work_accident', 'split=', -1)
# 0
# ('YES', 'split=', -1)
# 'IT'
# ('Work_accident', 'split=', -1)
# 0
# ('YES', 'split=', -1)
# '<=0.38'
# ('Work_accident', 'split=', -1)
# 0
# ('average_montly_hours', 'split=', 146)
# '<=146'
# ('sales', 'split=', -1)
# 'support'
# ('YES', 'split=', -1)
# 'sales'
# ('YES', 'split=', -1)
# '>146'
# ('sales', 'split=', -1)
# 'sales'
# ('NO', 'split=', -1)
# 'low'
# ('sales', 'split=', -1)
# 'product_mng'
# ('Work_accident', 'split=', -1)
# 0
# ('promotion_last_5years', 'split=', -1)
# 0
# ('YES', 'split=', -1)
# 1
# ('promotion_last_5years', 'split=', -1)
# 0
# ('YES', 'split=', -1)
# 'technical'
# ('Work_accident', 'split=', -1)
# 0
# ('promotion_last_5years', 'split=', -1)
# 0
# ('YES', 'split=', -1)
# 'marketing'
# ('Work_accident', 'split=', -1)
# 0
# ('promotion_last_5years', 'split=', -1)
# 0
# ('YES', 'split=', -1)
# 'support'
# ('Work_accident', 'split=', -1)
# 0
# ('promotion_last_5years', 'split=', -1)
# 0
# ('YES', 'split=', -1)
# 'sales'
# ('Work_accident', 'split=', -1)
# 0
# ('promotion_last_5years', 'split=', -1)
# 0
# ('YES', 'split=', -1)
# 'IT'
# ('Work_accident', 'split=', -1)
# 0
# ('promotion_last_5years', 'split=', -1)
# 0
# ('YES', 'split=', -1)
# 1
# ('YES', 'split=', -1)
# '>0.45'
# ('salary', 'split=', -1)
# 'high'
# ('Work_accident', 'split=', -1)
# 0
# ('promotion_last_5years', 'split=', -1)
# 0
# ('sales', 'split=', -1)
# 'product_mng'
# ('YES', 'split=', -1)
# 'technical'
# ('YES', 'split=', -1)
# 'marketing'
# ('YES', 'split=', -1)
# 'support'
# ('YES', 'split=', -1)
# 'sales'
# ('YES', 'split=', -1)
# 'RandD'
# ('YES', 'split=', -1)
# 'IT'
# ('NO', 'split=', -1)
# 'accounting'
# ('YES', 'split=', -1)
# 'medium'
# ('Work_accident', 'split=', -1)
# 0
# ('promotion_last_5years', 'split=', -1)
# 0
# ('sales', 'split=', -1)
# 'management'
# ('YES', 'split=', -1)
# 'product_mng'
# ('YES', 'split=', -1)
# 'technical'
# ('YES', 'split=', -1)
# 'marketing'
# ('YES', 'split=', -1)
# 'support'
# ('YES', 'split=', -1)
# 'IT'
# ('YES', 'split=', -1)
# 'RandD'
# ('YES', 'split=', -1)
# 'sales'
# ('YES', 'split=', -1)
# 'hr'
# ('YES', 'split=', -1)
# 'accounting'
# ('YES', 'split=', -1)
# 1
# ('sales', 'split=', -1)
# 'support'
# ('YES', 'split=', -1)
# 'IT'
# ('YES', 'split=', -1)
# 1
# ('promotion_last_5years', 'split=', -1)
# 0
# ('sales', 'split=', -1)
# 'product_mng'
# ('YES', 'split=', -1)
# 'technical'
# ('YES', 'split=', -1)
# 'marketing'
# ('YES', 'split=', -1)
# 'support'
# ('YES', 'split=', -1)
# 'sales'
# ('YES', 'split=', -1)
# 'hr'
# ('YES', 'split=', -1)
# 'accounting'
# ('YES', 'split=', -1)
# 'low'
# ('sales', 'split=', -1)
# 'management'
# ('Work_accident', 'split=', -1)
# 0
# ('promotion_last_5years', 'split=', -1)
# 0
# ('YES', 'split=', -1)
# 1
# ('promotion_last_5years', 'split=', -1)
# 0
# ('YES', 'split=', -1)
# 'product_mng'
# ('Work_accident', 'split=', -1)
# 0
# ('promotion_last_5years', 'split=', -1)
# 0
# ('YES', 'split=', -1)
# 1
# ('promotion_last_5years', 'split=', -1)
# 0
# ('YES', 'split=', -1)
# 'hr'
# ('Work_accident', 'split=', -1)
# 0
# ('promotion_last_5years', 'split=', -1)
# 0
# ('YES', 'split=', -1)
# 1
# ('promotion_last_5years', 'split=', -1)
# 0
# ('YES', 'split=', -1)
# 'marketing'
# ('Work_accident', 'split=', -1)
# 0
# ('promotion_last_5years', 'split=', -1)
# 0
# ('YES', 'split=', -1)
# 'support'
# ('Work_accident', 'split=', -1)
# 0
# ('promotion_last_5years', 'split=', -1)
# 0
# ('YES', 'split=', -1)
# 1
# ('promotion_last_5years', 'split=', -1)
# 0
# ('YES', 'split=', -1)
# 'sales'
# ('Work_accident', 'split=', -1)
# 0
# ('YES', 'split=', -1)
# 1
# ('promotion_last_5years', 'split=', -1)
# 0
# ('YES', 'split=', -1)
# 1
# ('YES', 'split=', -1)
# 'RandD'
# ('Work_accident', 'split=', -1)
# 0
# ('promotion_last_5years', 'split=', -1)
# 0
# ('YES', 'split=', -1)
# 'IT'
# ('Work_accident', 'split=', -1)
# 0
# ('promotion_last_5years', 'split=', -1)
# 0
# ('YES', 'split=', -1)
# 1
# ('promotion_last_5years', 'split=', -1)
# 0
# ('YES', 'split=', -1)
# 'technical'
# ('Work_accident', 'split=', -1)
# 0
# ('promotion_last_5years', 'split=', -1)
# 0
# ('YES', 'split=', -1)
# 1
# ('promotion_last_5years', 'split=', -1)
# 0
# ('YES', 'split=', -1)
# 'accounting'
# ('Work_accident', 'split=', -1)
# 0
# ('promotion_last_5years', 'split=', -1)
# 0
# ('YES', 'split=', -1)
# '<=126'
# ('Work_accident', 'split=', -1)
# 0
# ('promotion_last_5years', 'split=', -1)
# 0
# ('sales', 'split=', -1)
# 'hr'
# ('salary', 'split=', -1)
# 'medium'
# ('NO', 'split=', -1)
# 'low'
# ('YES', 'split=', -1)
# 'support'
# ('salary', 'split=', -1)
# 'medium'
# ('YES', 'split=', -1)
# 'sales'
# ('salary', 'split=', -1)
# 'medium'
# ('NO', 'split=', -1)
# 'low'
# ('YES', 'split=', -1)
# 'RandD'
# ('salary', 'split=', -1)
# 'low'
# ('NO', 'split=', -1)
# 'IT'
# ('salary', 'split=', -1)
# 'medium'
# ('NO', 'split=', -1)
# 'low'
# ('NO', 'split=', -1)
# 'technical'
# ('salary', 'split=', -1)
# 'medium'
# ('NO', 'split=', -1)
# 'low'
# ('YES', 'split=', -1)
# '>0.57'
# ('promotion_last_5years', 'split=', -1)
# 0
# ('sales', 'split=', -1)
# 'management'
# ('Work_accident', 'split=', -1)
# 0
# ('salary', 'split=', -1)
# 'high'
# ('NO', 'split=', -1)
# 'product_mng'
# ('Work_accident', 'split=', -1)
# 0
# ('salary', 'split=', -1)
# 'medium'
# ('NO', 'split=', -1)
# 'low'
# ('NO', 'split=', -1)
# 'technical'
# ('salary', 'split=', -1)
# 'high'
# ('Work_accident', 'split=', -1)
# 0
# ('NO', 'split=', -1)
# 'medium'
# ('Work_accident', 'split=', -1)
# 0
# ('NO', 'split=', -1)
# 'low'
# ('Work_accident', 'split=', -1)
# 0
# ('YES', 'split=', -1)
# 1
# ('NO', 'split=', -1)
# 'marketing'
# ('Work_accident', 'split=', -1)
# 0
# ('salary', 'split=', -1)
# 'medium'
# ('NO', 'split=', -1)
# 'support'
# ('Work_accident', 'split=', -1)
# 0
# ('salary', 'split=', -1)
# 'medium'
# ('NO', 'split=', -1)
# 'sales'
# ('Work_accident', 'split=', -1)
# 0
# ('salary', 'split=', -1)
# 'medium'
# ('NO', 'split=', -1)
# 'low'
# ('NO', 'split=', -1)
# 1
# ('salary', 'split=', -1)
# 'medium'
# ('NO', 'split=', -1)
# 'low'
# ('NO', 'split=', -1)
# 'RandD'
# ('Work_accident', 'split=', -1)
# 0
# ('salary', 'split=', -1)
# 'high'
# ('NO', 'split=', -1)
# 'accounting'
# ('Work_accident', 'split=', -1)
# 1
# ('salary', 'split=', -1)
# 'low'
# ('NO', 'split=', -1)
# '>2'
# ('satisfaction_level', 'split=', 0.12)
# '<=0.12'
# ('last_evaluation', 'split=', 0.72999999999999998)
# '>0.73'
# ('average_montly_hours', 'split=', 236)
# '<=236'
# ('Work_accident', 'split=', -1)
# 0
# ('promotion_last_5years', 'split=', -1)
# 0
# ('sales', 'split=', -1)
# 'hr'
# ('salary', 'split=', -1)
# 'medium'
# ('YES', 'split=', -1)
# 'technical'
# ('salary', 'split=', -1)
# 'medium'
# ('NO', 'split=', -1)
# 'low'
# ('YES', 'split=', -1)
# 'support'
# ('salary', 'split=', -1)
# 'medium'
# ('YES', 'split=', -1)
# 'low'
# ('NO', 'split=', -1)
# 'sales'
# ('salary', 'split=', -1)
# 'medium'
# ('NO', 'split=', -1)
# '>236'
# ('sales', 'split=', -1)
# 'management'
# ('Work_accident', 'split=', -1)
# 0
# ('promotion_last_5years', 'split=', -1)
# 0
# ('salary', 'split=', -1)
# 'medium'
# ('YES', 'split=', -1)
# 'low'
# ('YES', 'split=', -1)
# 'product_mng'
# ('Work_accident', 'split=', -1)
# 0
# ('promotion_last_5years', 'split=', -1)
# 0
# ('salary', 'split=', -1)
# 'high'
# ('YES', 'split=', -1)
# 'medium'
# ('YES', 'split=', -1)
# 'low'
# ('YES', 'split=', -1)
# 'technical'
# ('Work_accident', 'split=', -1)
# 0
# ('promotion_last_5years', 'split=', -1)
# 0
# ('salary', 'split=', -1)
# 'high'
# ('YES', 'split=', -1)
# 'medium'
# ('YES', 'split=', -1)
# 'low'
# ('YES', 'split=', -1)
# 1
# ('salary', 'split=', -1)
# 'low'
# ('YES', 'split=', -1)
# 1
# ('promotion_last_5years', 'split=', -1)
# 0
# ('salary', 'split=', -1)
# 'low'
# ('YES', 'split=', -1)
# 'marketing'
# ('Work_accident', 'split=', -1)
# 0
# ('promotion_last_5years', 'split=', -1)
# 0
# ('salary', 'split=', -1)
# 'medium'
# ('YES', 'split=', -1)
# 'low'
# ('YES', 'split=', -1)
# 'support'
# ('Work_accident', 'split=', -1)
# 0
# ('promotion_last_5years', 'split=', -1)
# 0
# ('salary', 'split=', -1)
# 'medium'
# ('YES', 'split=', -1)
# 'low'
# ('YES', 'split=', -1)
# 1
# ('promotion_last_5years', 'split=', -1)
# 0
# ('salary', 'split=', -1)
# 'low'
# ('YES', 'split=', -1)
# 'sales'
# ('Work_accident', 'split=', -1)
# 0
# ('promotion_last_5years', 'split=', -1)
# 0
# ('salary', 'split=', -1)
# 'high'
# ('YES', 'split=', -1)
# 'medium'
# ('YES', 'split=', -1)
# 'low'
# ('YES', 'split=', -1)
# 1
# ('promotion_last_5years', 'split=', -1)
# 0
# ('salary', 'split=', -1)
# 'medium'
# ('YES', 'split=', -1)
# 'low'
# ('YES', 'split=', -1)
# 'RandD'
# ('promotion_last_5years', 'split=', -1)
# 0
# ('Work_accident', 'split=', -1)
# 0
# ('salary', 'split=', -1)
# 'medium'
# ('YES', 'split=', -1)
# 'low'
# ('YES', 'split=', -1)
# 1
# ('salary', 'split=', -1)
# 'medium'
# ('YES', 'split=', -1)
# 'low'
# ('NO', 'split=', -1)
# 'IT'
# ('Work_accident', 'split=', -1)
# 0
# ('promotion_last_5years', 'split=', -1)
# 0
# ('salary', 'split=', -1)
# 'medium'
# ('YES', 'split=', -1)
# 'low'
# ('YES', 'split=', -1)
# 1
# ('promotion_last_5years', 'split=', -1)
# 0
# ('salary', 'split=', -1)
# 'low'
# ('YES', 'split=', -1)
# 'hr'
# ('Work_accident', 'split=', -1)
# 0
# ('promotion_last_5years', 'split=', -1)
# 0
# ('salary', 'split=', -1)
# 'high'
# ('YES', 'split=', -1)
# 'medium'
# ('YES', 'split=', -1)
# 'low'
# ('YES', 'split=', -1)
# 'accounting'
# ('Work_accident', 'split=', -1)
# 0
# ('promotion_last_5years', 'split=', -1)
# 0
# ('salary', 'split=', -1)
# 'medium'
# ('YES', 'split=', -1)
# 'low'
# ('YES', 'split=', -1)
# 1
# ('promotion_last_5years', 'split=', -1)
# 0
# ('salary', 'split=', -1)
# 'low'
# ('YES', 'split=', -1)
# '<=0.73'
# ('Work_accident', 'split=', -1)
# 0
# ('promotion_last_5years', 'split=', -1)
# 0
# ('sales', 'split=', -1)
# 'technical'
# ('salary', 'split=', -1)
# 'low'
# ('NO', 'split=', -1)
# 'support'
# ('salary', 'split=', -1)
# 'medium'
# ('NO', 'split=', -1)
# 'sales'
# ('salary', 'split=', -1)
# 'medium'
# ('NO', 'split=', -1)
# 'RandD'
# ('salary', 'split=', -1)
# 'high'
# ('NO', 'split=', -1)
# 'IT'
# ('salary', 'split=', -1)
# 'low'
# ('NO', 'split=', -1)
# 'accounting'
# ('salary', 'split=', -1)
# 'low'
# ('YES', 'split=', -1)
# '>0.12'
# ('number_project', 'split=', 5)
# '<=5'
# ('sales', 'split=', -1)
# 'management'
# ('salary', 'split=', -1)
# 'high'
# ('Work_accident', 'split=', -1)
# 0
# ('promotion_last_5years', 'split=', -1)
# 0
# ('NO', 'split=', -1)
# 1
# ('NO', 'split=', -1)
# 'medium'
# ('Work_accident', 'split=', -1)
# 0
# ('promotion_last_5years', 'split=', -1)
# 0
# ('NO', 'split=', -1)
# 1
# ('NO', 'split=', -1)
# 1
# ('promotion_last_5years', 'split=', -1)
# 0
# ('NO', 'split=', -1)
# 'low'
# ('Work_accident', 'split=', -1)
# 0
# ('promotion_last_5years', 'split=', -1)
# 0
# ('NO', 'split=', -1)
# 'product_mng'
# ('Work_accident', 'split=', -1)
# 0
# ('promotion_last_5years', 'split=', -1)
# 0
# ('salary', 'split=', -1)
# 'high'
# ('NO', 'split=', -1)
# 'medium'
# ('NO', 'split=', -1)
# 'low'
# ('NO', 'split=', -1)
# 1
# ('promotion_last_5years', 'split=', -1)
# 0
# ('salary', 'split=', -1)
# 'high'
# ('NO', 'split=', -1)
# 'medium'
# ('NO', 'split=', -1)
# 'low'
# ('NO', 'split=', -1)
# 'technical'
# ('promotion_last_5years', 'split=', -1)
# 0
# ('average_montly_hours', 'split=', 183)
# '>183'
# ('last_evaluation', 'split=', 0.53000000000000003)
# '>0.53'
# ('average_montly_hours', 'split=', 188)
# '>188'
# ('salary', 'split=', -1)
# 'high'
# ('Work_accident', 'split=', -1)
# 0
# ('NO', 'split=', -1)
# 'medium'
# ('Work_accident', 'split=', -1)
# 0
# ('NO', 'split=', -1)
# 1
# ('NO', 'split=', -1)
# 'low'
# ('Work_accident', 'split=', -1)
# 0
# ('NO', 'split=', -1)
# 1
# ('NO', 'split=', -1)
# '<=188'
# ('Work_accident', 'split=', -1)
# 0
# ('salary', 'split=', -1)
# 'low'
# ('YES', 'split=', -1)
# 1
# ('salary', 'split=', -1)
# 'medium'
# ('NO', 'split=', -1)
# '<=0.53'
# ('Work_accident', 'split=', -1)
# 0
# ('salary', 'split=', -1)
# 'medium'
# ('satisfaction_level', 'split=', 0.28000000000000003)
# '<=0.28'
# ('NO', 'split=', -1)
# '>0.28'
# ('YES', 'split=', -1)
# 'low'
# ('NO', 'split=', -1)
# '<=183'
# ('Work_accident', 'split=', -1)
# 0
# ('salary', 'split=', -1)
# 'high'
# ('NO', 'split=', -1)
# 'medium'
# ('NO', 'split=', -1)
# 'low'
# ('NO', 'split=', -1)
# 1
# ('salary', 'split=', -1)
# 'high'
# ('NO', 'split=', -1)
# 'medium'
# ('NO', 'split=', -1)
# 'low'
# ('NO', 'split=', -1)
# 'marketing'
# ('salary', 'split=', -1)
# 'high'
# ('Work_accident', 'split=', -1)
# 0
# ('promotion_last_5years', 'split=', -1)
# 0
# ('NO', 'split=', -1)
# 1
# ('promotion_last_5years', 'split=', -1)
# 0
# ('NO', 'split=', -1)
# 'medium'
# ('Work_accident', 'split=', -1)
# 0
# ('promotion_last_5years', 'split=', -1)
# 0
# ('NO', 'split=', -1)
# 1
# ('NO', 'split=', -1)
# 1
# ('promotion_last_5years', 'split=', -1)
# 0
# ('NO', 'split=', -1)
# 'low'
# ...
# 'hr'
# ('last_evaluation', 'split=', 0.85999999999999999)
# '>0.86'
# ('Work_accident', 'split=', -1)
# 0
# ('promotion_last_5years', 'split=', -1)
# 0
# ('salary', 'split=', -1)
# 'medium'
# ('satisfaction_level', 'split=', 0.70999999999999996)
# '<=0.71'
# ('YES', 'split=', -1)
# '>0.71'
# ('NO', 'split=', -1)
# 'low'
# ('NO', 'split=', -1)
# '<=0.86'
# ('salary', 'split=', -1)
# 'high'
# ('Work_accident', 'split=', -1)
# 0
# ('promotion_last_5years', 'split=', -1)
# 0
# ('NO', 'split=', -1)
# 1
# ('promotion_last_5years', 'split=', -1)
# 0
# ('NO', 'split=', -1)
# 'medium'
# ('Work_accident', 'split=', -1)
# 0
# ('promotion_last_5years', 'split=', -1)
# 0
# ('NO', 'split=', -1)
# 1
# ('NO', 'split=', -1)
# 'low'
# ('promotion_last_5years', 'split=', -1)
# 0
# ('Work_accident', 'split=', -1)
# 0
# ('NO', 'split=', -1)
# 1
# ('NO', 'split=', -1)
# 'accounting'
# ('promotion_last_5years', 'split=', -1)
# 0
# ('salary', 'split=', -1)
# 'high'
# ('Work_accident', 'split=', -1)
# 0
# ('NO', 'split=', -1)
# 'medium'
# ('Work_accident', 'split=', -1)
# 0
# ('NO', 'split=', -1)
# 1
# ('NO', 'split=', -1)
# 'low'
# ('Work_accident', 'split=', -1)
# 0
# ('NO', 'split=', -1)
# 1
# ('NO', 'split=', -1)
# '<=3'
# ('sales', 'split=', -1)
# 'management'
# ('average_montly_hours', 'split=', 274)
# '<=274'
# ('promotion_last_5years', 'split=', -1)
# 0
# ('Work_accident', 'split=', -1)
# 0
# ('salary', 'split=', -1)
# 'high'
# ('NO', 'split=', -1)
# 'medium'
# ('NO', 'split=', -1)
# 'low'
# ('NO', 'split=', -1)
# 1
# ('salary', 'split=', -1)
# 'high'
# ('NO', 'split=', -1)
# 'medium'
# ('NO', 'split=', -1)
# 'low'
# ('NO', 'split=', -1)
# 1
# ('salary', 'split=', -1)
# 'high'
# ('Work_accident', 'split=', -1)
# 0
# ('NO', 'split=', -1)
# 1
# ('NO', 'split=', -1)
# 'medium'
# ('Work_accident', 'split=', -1)
# 0
# ('NO', 'split=', -1)
# 'low'
# ('Work_accident', 'split=', -1)
# 0
# ('YES', 'split=', -1)
# 1
# ('NO', 'split=', -1)
# '>274'
# ('Work_accident', 'split=', -1)
# 0
# ('promotion_last_5years', 'split=', -1)
# 0
# ('salary', 'split=', -1)
# 'medium'
# ('NO', 'split=', -1)
# 'low'
# ('NO', 'split=', -1)
# 'product_mng'
# ('Work_accident', 'split=', -1)
# 0
# ('promotion_last_5years', 'split=', -1)
# 0
# ('salary', 'split=', -1)
# 'high'
# ('NO', 'split=', -1)
# 'medium'
# ('NO', 'split=', -1)
# 'low'
# ('NO', 'split=', -1)
# 1
# ('promotion_last_5years', 'split=', -1)
# 0
# ('salary', 'split=', -1)
# 'high'
# ('NO', 'split=', -1)
# 'medium'
# ('NO', 'split=', -1)
# 'low'
# ('NO', 'split=', -1)
# 'technical'
# ('average_montly_hours', 'split=', 134)
# '>134'
# ('salary', 'split=', -1)
# 'high'
# ('Work_accident', 'split=', -1)
# 0
# ('promotion_last_5years', 'split=', -1)
# 0
# ('NO', 'split=', -1)
# 1
# ('promotion_last_5years', 'split=', -1)
# 0
# ('NO', 'split=', -1)
# 'medium'
# ('Work_accident', 'split=', -1)
# 0
# ('NO', 'split=', -1)
# 1
# ('promotion_last_5years', 'split=', -1)
# 0
# ('NO', 'split=', -1)
# 1
# ('NO', 'split=', -1)
# 'low'
# ('Work_accident', 'split=', -1)
# 0
# ('promotion_last_5years', 'split=', -1)
# 0
# ('NO', 'split=', -1)
# 1
# ('NO', 'split=', -1)
# 1
# ('promotion_last_5years', 'split=', -1)
# 0
# ('NO', 'split=', -1)
# 1
# ('NO', 'split=', -1)
# '<=134'
# ('salary', 'split=', -1)
# 'high'
# ('Work_accident', 'split=', -1)
# 0
# ('promotion_last_5years', 'split=', -1)
# 0
# ('NO', 'split=', -1)
# 'medium'
# ('Work_accident', 'split=', -1)
# 0
# ('promotion_last_5years', 'split=', -1)
# 0
# ('NO', 'split=', -1)
# 1
# ('NO', 'split=', -1)
# 'low'
# ('promotion_last_5years', 'split=', -1)
# 0
# ('Work_accident', 'split=', -1)
# 0
# ('NO', 'split=', -1)
# 1
# ('NO', 'split=', -1)
# 'marketing'
# ('Work_accident', 'split=', -1)
# 0
# ('promotion_last_5years', 'split=', -1)
# 0
# ('salary', 'split=', -1)
# 'high'
# ('NO', 'split=', -1)
# 'medium'
# ('NO', 'split=', -1)
# 'low'
# ('NO', 'split=', -1)
# 1
# ('salary', 'split=', -1)
# 'high'
# ('NO', 'split=', -1)
# 'medium'
# ('NO', 'split=', -1)
# 'low'
# ('NO', 'split=', -1)
# 1
# ('promotion_last_5years', 'split=', -1)
# 0
# ('salary', 'split=', -1)
# 'high'
# ('NO', 'split=', -1)
# 'medium'
# ('NO', 'split=', -1)
# 'low'
# ('NO', 'split=', -1)
# 1
# ('salary', 'split=', -1)
# 'medium'
# ('NO', 'split=', -1)
# 'low'
# ('NO', 'split=', -1)
# 'support'
# ('satisfaction_level', 'split=', 0.48999999999999999)
# '>0.49'
# ('last_evaluation', 'split=', 0.78000000000000003)
# '<=0.78'
# ('salary', 'split=', -1)
# 'high'
# ('Work_accident', 'split=', -1)
# 0
# ('promotion_last_5years', 'split=', -1)
# 0
# ('NO', 'split=', -1)
# 1
# ('promotion_last_5years', 'split=', -1)
# 0
# ('NO', 'split=', -1)
# 'medium'
# ('Work_accident', 'split=', -1)
# 0
# ('promotion_last_5years', 'split=', -1)
# 0
# ('NO', 'split=', -1)
# 1
# ('NO', 'split=', -1)
# 1
# ('promotion_last_5years', 'split=', -1)
# 0
# ('NO', 'split=', -1)
# 'low'
# ('Work_accident', 'split=', -1)
# 0
# ('promotion_last_5years', 'split=', -1)
# 0
# ('NO', 'split=', -1)
# 1
# ('NO', 'split=', -1)
# 1
# ('promotion_last_5years', 'split=', -1)
# 0
# ('NO', 'split=', -1)
# '>0.78'
# ('last_evaluation', 'split=', 0.79000000000000004)
# '<=0.79'
# ('salary', 'split=', -1)
# 'high'
# ('Work_accident', 'split=', -1)
# 0
# ('promotion_last_5years', 'split=', -1)
# 0
# ('NO', 'split=', -1)
# 1
# ('promotion_last_5years', 'split=', -1)
# 0
# ('NO', 'split=', -1)
# 'medium'
# ('promotion_last_5years', 'split=', -1)
# 0
# ('Work_accident', 'split=', -1)
# 0
# ('NO', 'split=', -1)
# 1
# ('NO', 'split=', -1)
# 1
# ('Work_accident', 'split=', -1)
# 0
# ('NO', 'split=', -1)
# 'low'
# ('Work_accident', 'split=', -1)
# 0
# ('promotion_last_5years', 'split=', -1)
# 0
# ('NO', 'split=', -1)
# '>0.79'
# ('average_montly_hours', 'split=', 248)
# '<=248'
# ('salary', 'split=', -1)
# 'high'
# ('Work_accident', 'split=', -1)
# 0
# ('promotion_last_5years', 'split=', -1)
# 0
# ('NO', 'split=', -1)
# 1
# ('promotion_last_5years', 'split=', -1)
# 0
# ('NO', 'split=', -1)
# 'medium'
# ('promotion_last_5years', 'split=', -1)
# 0
# ('Work_accident', 'split=', -1)
# 0
# ('NO', 'split=', -1)
# 1
# ('NO', 'split=', -1)
# 'low'
# ('Work_accident', 'split=', -1)
# 0
# ('promotion_last_5years', 'split=', -1)
# 0
# ('NO', 'split=', -1)
# 1
# ('NO', 'split=', -1)
# 1
# ('promotion_last_5years', 'split=', -1)
# 0
# ('NO', 'split=', -1)
# '>248'
# ('promotion_last_5years', 'split=', -1)
# 0
# ('salary', 'split=', -1)
# 'high'
# ('Work_accident', 'split=', -1)
# 0
# ('NO', 'split=', -1)
# 1
# ('NO', 'split=', -1)
# 'medium'
# ('Work_accident', 'split=', -1)
# 0
# ('NO', 'split=', -1)
# 1
# ('NO', 'split=', -1)
# 'low'
# ('Work_accident', 'split=', -1)
# 0
# ('NO', 'split=', -1)
# 1
# ('NO', 'split=', -1)
# '<=0.49'
# ('promotion_last_5years', 'split=', -1)
# 0
# ('salary', 'split=', -1)
# 'high'
# ('Work_accident', 'split=', -1)
# 0
# ('NO', 'split=', -1)
# 'medium'
# ('Work_accident', 'split=', -1)
# 0
# ('NO', 'split=', -1)
# 1
# ('NO', 'split=', -1)
# 'low'
# ('Work_accident', 'split=', -1)
# 0
# ('NO', 'split=', -1)
# 1
# ('NO', 'split=', -1)
# 'sales'
# ('satisfaction_level', 'split=', 0.56999999999999995)
# '<=0.57'
# ('satisfaction_level', 'split=', 0.53000000000000003)
# '>0.53'
# ('satisfaction_level', 'split=', 0.54000000000000004)
# '<=0.54'
# ('promotion_last_5years', 'split=', -1)
# 0
# ('last_evaluation', 'split=', 0.63)
# '>0.63'
# ('Work_accident', 'split=', -1)
# 0
# ('salary', 'split=', -1)
# 'low'
# ('YES', 'split=', -1)
# 1
# ('salary', 'split=', -1)
# 'low'
# ('NO', 'split=', -1)
# '<=0.63'
# ('Work_accident', 'split=', -1)
# 0
# ('salary', 'split=', -1)
# 'medium'
# ('NO', 'split=', -1)
# 'low'
# ('NO', 'split=', -1)
# '>0.54'
# ('salary', 'split=', -1)
# 'high'
# ('Work_accident', 'split=', -1)
# 0
# ('promotion_last_5years', 'split=', -1)
# 0
# ('NO', 'split=', -1)
# 'medium'
# ('Work_accident', 'split=', -1)
# 0
# ('promotion_last_5years', 'split=', -1)
# 0
# ('NO', 'split=', -1)
# 1
# ('promotion_last_5years', 'split=', -1)
# 0
# ('NO', 'split=', -1)
# 1
# ('NO', 'split=', -1)
# 'low'
# ('Work_accident', 'split=', -1)
# 0
# ('promotion_last_5years', 'split=', -1)
# 0
# ('NO', 'split=', -1)
# 1
# ('NO', 'split=', -1)
# 1
# ('promotion_last_5years', 'split=', -1)
# 0
# ('NO', 'split=', -1)
# '<=0.53'
# ('salary', 'split=', -1)
# 'high'
# ('Work_accident', 'split=', -1)
# 0
# ('promotion_last_5years', 'split=', -1)
# 0
# ('NO', 'split=', -1)
# 1
# ('promotion_last_5years', 'split=', -1)
# 0
# ('NO', 'split=', -1)
# 'medium'
# ('Work_accident', 'split=', -1)
# 0
# ('promotion_last_5years', 'split=', -1)
# 0
# ('NO', 'split=', -1)
# 1
# ('NO', 'split=', -1)
# 1
# ('promotion_last_5years', 'split=', -1)
# 0
# ('NO', 'split=', -1)
# 1
# ('NO', 'split=', -1)
# 'low'
# ('promotion_last_5years', 'split=', -1)
# 0
# ('Work_accident', 'split=', -1)
# 0
# ('NO', 'split=', -1)
# 1
# ('NO', 'split=', -1)
# '>0.57'
# ('last_evaluation', 'split=', 0.45000000000000001)
# '<=0.45'
# ('promotion_last_5years', 'split=', -1)
# 0
# ('salary', 'split=', -1)
# 'high'
# ('Work_accident', 'split=', -1)
# 0
# ('NO', 'split=', -1)
# 'medium'
# ('Work_accident', 'split=', -1)
# 0
# ('NO', 'split=', -1)
# 1
# ('NO', 'split=', -1)
# 'low'
# ('Work_accident', 'split=', -1)
# 0
# ('NO', 'split=', -1)
# '>0.45'
# ('average_montly_hours', 'split=', 267)
# '>267'
# ('salary', 'split=', -1)
# 'high'
# ('Work_accident', 'split=', -1)
# 0
# ('promotion_last_5years', 'split=', -1)
# 0
# ('NO', 'split=', -1)
# 'medium'
# ('Work_accident', 'split=', -1)
# 0
# ('promotion_last_5years', 'split=', -1)
# 0
# ('NO', 'split=', -1)
# 1
# ('promotion_last_5years', 'split=', -1)
# 0
# ('NO', 'split=', -1)
# 1
# ('NO', 'split=', -1)
# 'low'
# ('Work_accident', 'split=', -1)
# 0
# ('promotion_last_5years', 'split=', -1)
# 0
# ('NO', 'split=', -1)
# 1
# ('promotion_last_5years', 'split=', -1)
# 0
# ('NO', 'split=', -1)
# '<=267'
# ('salary', 'split=', -1)
# 'high'
# ('Work_accident', 'split=', -1)
# 0
# ('promotion_last_5years', 'split=', -1)
# 0
# ('NO', 'split=', -1)
# 1
# ('NO', 'split=', -1)
# 1
# ('promotion_last_5years', 'split=', -1)
# 0
# ('NO', 'split=', -1)
# 'medium'
# ('Work_accident', 'split=', -1)
# 0
# ('promotion_last_5years', 'split=', -1)
# 0
# ('NO', 'split=', -1)
# 1
# ('NO', 'split=', -1)
# 1
# ('promotion_last_5years', 'split=', -1)
# 0
# ('NO', 'split=', -1)
# 1
# ('NO', 'split=', -1)
# 'low'
# ('average_montly_hours', 'split=', 215)
# '>215'
# ('promotion_last_5years', 'split=', -1)
# 0
# ('average_montly_hours', 'split=', 216)
# '>216'
# ('Work_accident', 'split=', -1)
# 0
# ('NO', 'split=', -1)
# 1
# ('NO', 'split=', -1)
# '<=216'
# ('Work_accident', 'split=', -1)
# 0
# ('NO', 'split=', -1)
# '<=215'
# ('Work_accident', 'split=', -1)
# 0
# ('NO', 'split=', -1)
# 1
# ('promotion_last_5years', 'split=', -1)
# 0
# ('NO', 'split=', -1)
# 'RandD'
# ('salary', 'split=', -1)
# 'high'
# ('Work_accident', 'split=', -1)
# 0
# ('promotion_last_5years', 'split=', -1)
# 0
# ('NO', 'split=', -1)
# 1
# ('NO', 'split=', -1)
# 1
# ('promotion_last_5years', 'split=', -1)
# 0
# ('NO', 'split=', -1)
# 'medium'
# ('Work_accident', 'split=', -1)
# 0
# ('promotion_last_5years', 'split=', -1)
# 0
# ('NO', 'split=', -1)
# 1
# ('NO', 'split=', -1)
# 1
# ('promotion_last_5years', 'split=', -1)
# 0
# ('NO', 'split=', -1)
# 1
# ('NO', 'split=', -1)
# 'low'
# ('Work_accident', 'split=', -1)
# 0
# ('promotion_last_5years', 'split=', -1)
# 0
# ('NO', 'split=', -1)
# 1
# ('promotion_last_5years', 'split=', -1)
# 0
# ('NO', 'split=', -1)
# 1
# ('NO', 'split=', -1)
# 'IT'
# ('Work_accident', 'split=', -1)
# 0
# ('promotion_last_5years', 'split=', -1)
# 0
# ('salary', 'split=', -1)
# 'high'
# ('NO', 'split=', -1)
# 'medium'
# ('NO', 'split=', -1)
# 'low'
# ('NO', 'split=', -1)
# 1
# ('promotion_last_5years', 'split=', -1)
# 0
# ('salary', 'split=', -1)
# 'high'
# ('NO', 'split=', -1)
# 'medium'
# ('NO', 'split=', -1)
# 'low'
# ('NO', 'split=', -1)
# 'hr'
# ('satisfaction_level', 'split=', 0.57999999999999996)
# '>0.58'
# ('salary', 'split=', -1)
# 'high'
# ('Work_accident', 'split=', -1)
# 0
# ('promotion_last_5years', 'split=', -1)
# 0
# ('NO', 'split=', -1)
# 1
# ('NO', 'split=', -1)
# 1
# ('promotion_last_5years', 'split=', -1)
# 0
# ('NO', 'split=', -1)
# 'medium'
# ('promotion_last_5years', 'split=', -1)
# 0
# ('Work_accident', 'split=', -1)
# 0
# ('NO', 'split=', -1)
# 1
# ('NO', 'split=', -1)
# 'low'
# ('Work_accident', 'split=', -1)
# 0
# ('promotion_last_5years', 'split=', -1)
# 0
# ('NO', 'split=', -1)
# 1
# ('NO', 'split=', -1)
# 1
# ('promotion_last_5years', 'split=', -1)
# 0
# ('NO', 'split=', -1)
# '<=0.58'
# ('promotion_last_5years', 'split=', -1)
# 0
# ('salary', 'split=', -1)
# 'high'
# ('Work_accident', 'split=', -1)
# 0
# ('NO', 'split=', -1)
# 1
# ('NO', 'split=', -1)
# 'medium'
# ('Work_accident', 'split=', -1)
# 0
# ('NO', 'split=', -1)
# 1
# ('NO', 'split=', -1)
# 'low'
# ('Work_accident', 'split=', -1)
# 0
# ('NO', 'split=', -1)
# 1
# ('NO', 'split=', -1)
# 'accounting'
# ('salary', 'split=', -1)
# 'high'
# ('Work_accident', 'split=', -1)
# 0
# ('promotion_last_5years', 'split=', -1)
# 0
# ('NO', 'split=', -1)
# 1
# ('NO', 'split=', -1)
# 1
# ('promotion_last_5years', 'split=', -1)
# 0
# ('NO', 'split=', -1)
# 'medium'
# ('Work_accident', 'split=', -1)
# 0
# ('promotion_last_5years', 'split=', -1)
# 0
# ('NO', 'split=', -1)
# 1
# ('NO', 'split=', -1)
# 1
# ('promotion_last_5years', 'split=', -1)
# 0
# ('NO', 'split=', -1)
# 'low'
# ('Work_accident', 'split=', -1)
# 0
# ('promotion_last_5years', 'split=', -1)
# 0
# ('NO', 'split=', -1)
# 1
# ('promotion_last_5years', 'split=', -1)
# 0
# ('NO', 'split=', -1)
# '>5'
# ('sales', 'split=', -1)
# 'management'
# ('promotion_last_5years', 'split=', -1)
# 0
# ('salary', 'split=', -1)
# 'medium'
# ('Work_accident', 'split=', -1)
# 0
# ('NO', 'split=', -1)
# 1
# ('NO', 'split=', -1)
# 'low'
# ('Work_accident', 'split=', -1)
# 1
# ('YES', 'split=', -1)
# 'product_mng'
# ('Work_accident', 'split=', -1)
# 0
# ('promotion_last_5years', 'split=', -1)
# 0
# ('salary', 'split=', -1)
# 'high'
# ('NO', 'split=', -1)
# 'medium'
# ('NO', 'split=', -1)
# 'low'
# ('NO', 'split=', -1)
# 1
# ('promotion_last_5years', 'split=', -1)
# 0
# ('salary', 'split=', -1)
# 'medium'
# ('NO', 'split=', -1)
# 'low'
# ('NO', 'split=', -1)
# 'hr'
# ('Work_accident', 'split=', -1)
# 0
# ('promotion_last_5years', 'split=', -1)
# 0
# ('salary', 'split=', -1)
# 'medium'
# ('NO', 'split=', -1)
# 'low'
# ('NO', 'split=', -1)
# 'marketing'
# ('promotion_last_5years', 'split=', -1)
# 0
# ('salary', 'split=', -1)
# 'medium'
# ('Work_accident', 'split=', -1)
# 0
# ('NO', 'split=', -1)
# 1
# ('NO', 'split=', -1)
# 'low'
# ('Work_accident', 'split=', -1)
# 0
# ('NO', 'split=', -1)
# 'support'
# ('salary', 'split=', -1)
# 'high'
# ('Work_accident', 'split=', -1)
# 0
# ('promotion_last_5years', 'split=', -1)
# 0
# ('NO', 'split=', -1)
# 'medium'
# ('Work_accident', 'split=', -1)
# 0
# ('promotion_last_5years', 'split=', -1)
# 0
# ('NO', 'split=', -1)
# 1
# ('promotion_last_5years', 'split=', -1)
# 1
# ('NO', 'split=', -1)
# 'low'
# ('Work_accident', 'split=', -1)
# 0
# ('promotion_last_5years', 'split=', -1)
# 0
# ('NO', 'split=', -1)
# 1
# ('promotion_last_5years', 'split=', -1)
# 0
# ('NO', 'split=', -1)
# 'sales'
# ('promotion_last_5years', 'split=', -1)
# 0
# ('average_montly_hours', 'split=', 246)
# '>246'
# ('Work_accident', 'split=', -1)
# 0
# ('salary', 'split=', -1)
# 'medium'
# ('NO', 'split=', -1)
# 'low'
# ('NO', 'split=', -1)
# '<=246'
# ('salary', 'split=', -1)
# 'high'
# ('Work_accident', 'split=', -1)
# 0
# ('NO', 'split=', -1)
# 1
# ('NO', 'split=', -1)
# 'medium'
# ('Work_accident', 'split=', -1)
# 0
# ('NO', 'split=', -1)
# 1
# ('NO', 'split=', -1)
# 'low'
# ('Work_accident', 'split=', -1)
# 0
# ('NO', 'split=', -1)
# 1
# ('NO', 'split=', -1)
# 'RandD'
# ('Work_accident', 'split=', -1)
# 0
# ('promotion_last_5years', 'split=', -1)
# 0
# ('salary', 'split=', -1)
# 'medium'
# ('NO', 'split=', -1)
# 1
# ('salary', 'split=', -1)
# 'low'
# ('NO', 'split=', -1)
# 1
# ('promotion_last_5years', 'split=', -1)
# 1
# ('salary', 'split=', -1)
# 'medium'
# ('NO', 'split=', -1)
# 'IT'
# ('promotion_last_5years', 'split=', -1)
# 0
# ('satisfaction_level', 'split=', 0.79000000000000004)
# '<=0.79'
# ('salary', 'split=', -1)
# 'high'
# ('Work_accident', 'split=', -1)
# 0
# ('NO', 'split=', -1)
# 'medium'
# ('Work_accident', 'split=', -1)
# 0
# ('NO', 'split=', -1)
# 1
# ('NO', 'split=', -1)
# 'low'
# ('Work_accident', 'split=', -1)
# 0
# ('NO', 'split=', -1)
# '>0.79'
# ('Work_accident', 'split=', -1)
# 0
# ('salary', 'split=', -1)
# 'medium'
# ('YES', 'split=', -1)
# 'low'
# ('NO', 'split=', -1)
# 'technical'
# ('Work_accident', 'split=', -1)
# 0
# ('satisfaction_level', 'split=', 0.58999999999999997)
# '>0.59'
# ('salary', 'split=', -1)
# 'high'
# ('promotion_last_5years', 'split=', -1)
# 0
# ('NO', 'split=', -1)
# 'medium'
# ('promotion_last_5years', 'split=', -1)
# 0
# ('NO', 'split=', -1)
# 1
# ('NO', 'split=', -1)
# 'low'
# ('promotion_last_5years', 'split=', -1)
# 0
# ('NO', 'split=', -1)
# '<=0.59'
# ('promotion_last_5years', 'split=', -1)
# 0
# ('salary', 'split=', -1)
# 'medium'
# ('NO', 'split=', -1)
# 'low'
# ('YES', 'split=', -1)
# 'accounting'
# ('Work_accident', 'split=', -1)
# 0
# ('promotion_last_5years', 'split=', -1)
# 0
# ('salary', 'split=', -1)
# 'high'
# ('NO', 'split=', -1)
# 'medium'
# ('NO', 'split=', -1)
# 'low'
# ('NO', 'split=', -1)
# '>286'
# ('Work_accident', 'split=', -1)
# 0
# ('promotion_last_5years', 'split=', -1)
# 0
# ('sales', 'split=', -1)
# 'hr'
# ('salary', 'split=', -1)
# 'low'
# ('YES', 'split=', -1)
# 'technical'
# ('salary', 'split=', -1)
# 'medium'
# ('NO', 'split=', -1)
# 'product_mng'
# ('salary', 'split=', -1)
# 'low'
# ('YES', 'split=', -1)
# 'IT'
# ('salary', 'split=', -1)
# 'medium'
# ('YES', 'split=', -1)
# 'sales'
# ('salary', 'split=', -1)
# 'medium'
# ('NO', 'split=', -1)

# %%
def predict(row,tree):
#     global tp,tn,fp,fn
    if tree.val=="YES" or tree.val=="NO":
        return tree.val
    
    attr=row[tree.val]
    
    if tree.val in numerical_attributes:
        if attr<=tree.spl_pt:
            x="<="+str(tree.spl_pt)
            return predict(row,tree.child[x])
        else:
            x=">"+str(tree.spl_pt)
            return predict(row,tree.child[x])
    else:
        if attr in tree.child:
            return predict(row,tree.child[attr])
    return "NO"

def predict1(df,tree):
    tp=0
    tn=0
    fp=0
    fn=0
    i=0
    while i< len(df):
        pred_val=predict(df.iloc[i],tree)
        if df.iloc[i]['left']==1:
            if pred_val=="YES":
                tp=tp+1
            else:
                fn=fn+1 #### fn here 
        elif df.iloc[i]['left']==0:
            if pred_val=="NO":
                tn=tn+1
            else:
                fp=fp+1 #### fp here
        i=i+1
#         print"i="
    return tp,fp,tn,fn
    
        
# row=df.iloc[8]
# print (row)
tp,fp,tn,fn=predict1(validate,tree_g)
print 'For gini index:-'
print "True Positive=\t",tp
print "True Negative=\t",tn
print "False positive=",fp
print "False negative=",fn
total=tp+tn+fp+fn
prec=tp/float(tp+fp)
rec=tp/float(tp+fn)
den=float((1/rec)+(1/prec))
f1=2/float(den)

print "Precision: ", prec
print "Recall: ",rec
print "F1 score: ",f1
print "accuracy: ",(tp+tn)/float(total)

# pred=predict(row,tree)
# pprint.pprint(pred)
# Out:
# For gini index:-
# True Positive=	518
# True Negative=	1672
# False positive= 17
# False negative= 41
# Precision:  0.968224299065
# Recall:  0.926654740608
# F1 score:  0.946983546618
# accuracy:  0.974199288256
